# %% [markdown]
# ## **Комментарий ревьюера**
#
# Привет 👋
#
# Меня зовут, и я буду проверять твой проект. Предлагаю сразу договориться общаться на «ты», если для тебя это не уместно, то дай, пожалуйста, знать, будем общаться на «вы».
#
# ### **Краткое резюме по ревью**
#
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Видны твои старания при работе над данным проектом. Большинство основных этапов в работе сделано хорошо:
# - есть много сильных и интересных алгоритмов 🤩
# - детально изучены многие тонкости данных
# - здорово сделана предобработка данных
# - качественно исследованы данные
# - построено много интересных графиков
# - сделано много верных промежуточных выводов, основанных на полученных данных
#
# Твоего внимания требует:
# - дополнение предобработки данных
# - оценка выбросов
# - небольшое исправление графиков
# - пересмотр выводов
#
# Я описал замечания в комментариях, которые помечены цветом(красным, желтым), после их доработки я смогу принять работу.
#
# Спасибо тебе за твой труд! Я на все 100% уверен, что у тебя все получится, и с нетерпением буду ждать твою работу на повторное ревью 😉
#
# </div>
#
# ### **PS:**
#
# Хочу поделиться дополнительным материалом, он бесплатный, но объемный(может уйти несколько месяцев):
# - У Тимофея Хирьянова есть [Плей-лист по алгоритмам на python](https://www.youtube.com/playlist?list=PLRDzFCPr95fK7tr47883DFUbm4GeOjjc0), это вроде просто видео-лекции, но в описании есть ссылка на лекции и практику, не стесняйся смотреть, преподаватель очень наглядно объясняет материал. На первых уроках задания могут показаться сложными, так как требует знания геометрии, не стесняйся проходить далее, будет проще)
#
# И вот доп ссылки на статьи по корреляции:
# - [Шкала Чеддока…](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/), тут есть табличка по тому, как интерпретировать корреляцию
# - [Линейный коэффициент корреляции Пирсона](https://statanaliz.info/statistica/korrelyaciya-i-regressiya/linejnyj-koefficient-korrelyacii-pirsona/)
# - [Корреляция и регрессия](https://stepik.org/lesson/8086/step/1?unit=1365), это небольшой курс на степике, в котором можно пройти только нужные тебе блоки
# - [Корреляция и каузальность](https://pikabu.ru/story/korrelyatsiya_i_kauzalnost_5956601)
#
# ### **Правила оформления:**
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Постарайся учесть эти комментарии для дальнейших проектов. Я использую заголовки в комментариях, они изменят твое оглавление. Но тебе будет удобно перемещаться от комментария к комментарию. А перед перемещением проекта в портфолио просто уберешь данные комментарии.
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Я буду красить комментарии цветом:
#
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h4> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h4>
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
#
# Также жду от тебя комментарии, где вкратце опишешь изменения, которые были внесены.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h4> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h4>
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
#
# В случае изменений кода, опиши, пожалуйста, вкратце то, что изменилось. Если изменений не было, то просто опиши свои мысли на эту тему.
# </div>
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h4> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h4>
#
# Такой комментарий говорит о том, что было сделано что-то качественное и правильное 😃
#
# Я не буду ждать твоего комментария, но буду ему очень рад 🤗
# </div>
#
# Чтобы мы были на одной волне, рекомендую общаться в том же стиле 😊 Твои ответы на мои комментарии будут подкрашиваться в синий цвет.
#
# Ниже я оформил образец для твоего удобства, тебе остается только добавить после моего комментария ячейку с типом **Markdown**, скопировать туда код(чтобы увидеть код дважды, кликни на ячейку) из образца и написать свои мысли по поводу комментария.

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Привет, Валентин. Давай на "ты". Здорово получить такую развернутую обратную связь.
# <br>
# Так как времени остается мало до конца дедлайна, буду кратко отвечать на твои комментарии.
# </div>

# %% [markdown]
# ## **Комментарий ревьюера v2**
#
# ### **Краткое резюме по ревью**
# <div style="border-radius: 15px; box-shadow: 2px 2px 4px; border: 1px solid; background:Gainsboro; padding: 20px">
#
# Молодец, исправлено:
# - дополнение предобработки данных
# - оценка выбросов
# - небольшое исправление графиков
# - пересмотр выводов
#
# Спасибо тебе за твой труд! Я готов принять работу. Успехов в дальнейшем обучении!
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# # Описание данных
#
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)<br>
# balcony — число балконов<br>
# ceiling_height — высота потолков (м)<br>
# cityCenters_nearest — расстояние до центра города (м)<br>
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)<br>
# first_day_exposition — дата публикации<br>
# floor — этаж<br>
# floors_total — всего этажей в доме<br>
# is_apartment — апартаменты (булев тип)<br>
# kitchen_area — площадь кухни в квадратных метрах (м²)<br>
# last_price — цена на момент снятия с публикации<br>
# living_area — жилая площадь в квадратных метрах (м²)<br>
# locality_name — название населённого пункта<br>
# open_plan — свободная планировка (булев тип)<br>
# parks_around3000 — число парков в радиусе 3 км<br>
# parks_nearest — расстояние до ближайшего парка (м)<br>
# ponds_around3000 — число водоёмов в радиусе 3 км<br>
# ponds_nearest — расстояние до ближайшего водоёма (м)<br>
# rooms — число комнат<br>
# studio — квартира-студия (булев тип)<br>
# total_area — площадь квартиры в квадратных метрах (м²)<br>
# total_images — число фотографий квартиры в объявлении<br>

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Спасибо, что есть оглавление в плагине toc. Теперь по проекту удобно перемещаться.
#
# Здорово, что во вступлении к твоему проекту есть
#
# - заголовок,
#
# - краткое описание проекта,
#
# - описание данных,
#
# - цель проекта
#
# Вступление станет лучше, если ты добавишь в него:
#
# - план работы
#
# Тогда получатель отчета сможет быстрей его понять.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
# <font color="SteelBlue">
#
#     План работы.
#
#     1. Загрузка файла с данными и изучение общей информации
#     2. Предобработка данных
#     3. Добавление в таблицу новых столбцов
#     4. Исследовательский анализ данных
#     5. Общий вывод
#
#     Пока оставлю так, понимаю, что можно доработать.
# </font></h5>
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Спасибо за дополнение вступления 👍
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd #импорт pandas
import matplotlib.pyplot as plt #импорт matplotlib
pd.set_option('display.max_columns', 50)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv') #загружаем файл с данными

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Импорт библиотек в отдельной ячейке.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Молодец, что загружаешь все библиотеки в начале проекта. Так сложней случайно удалить ячейку с загрузкой нужной библиотеки и сделать код не работающим. А получатель отчета сразу поймет, какие библиотеки ты используешь и какие ему нужно установить для запуска проекта. 👍
#
# </div>

# %%
data.columns #выведем на экран столбцы датасета
# Out:
# Index(['total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition'], dtype='object')

# %%
data.head() #выведем на экран первые 5 строк датасета
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Все данные находятся в одном столбце, необходим разделитель.

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') #добавим разделитель при чтении файла

# %%
data.head(10) #выведем на экран первые 10 строк датасета
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Все хорошо, хочу дать рекомендацию. При выводе df.head() можно увидеть, что часть столбцов заменилась на «...»
#
# Чтобы это поправить можно поправить настройки pandas:
#
# ```python
# pd.set_option('display.max_columns', 50)
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Спасибо, не знала об этой опции.
#
# </div>

# %%
data.tail(10) #выведем на экран последние 10 строк датасета
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23689            2.86          15.0         16.3      4          NaN   False
# ...

# %%
data.shape #выведем на экран инфо о размере датасета (строки, столбцы)
# Out:
# (23699, 22)

# %%
data.info() #выведем на экран общую информацию о датасете
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.describe() #обзор датасета по столбцам
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %%
data.hist(figsize=(15,20)) #построим гистограмму для всех столбцов таблицы
None

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Отлично, построены гистограммы по всем столбцам!
#
# Вывод перед графиком немного мешает. Он выводится так как jupyter notebook выводит на экран информацию об объекте в последней строке, чтобы этого не было, можно в конец добавить None, эти непонятные строки выводиться не будут. Показал в примере ниже.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Спасибо, так и сделала.
#
# </div>

# %%
# Код ревьюера

data.hist(figsize=(15, 20))
None

# %% [markdown]
# # Выводы
#
#
# Была изучена общая структура данных
#
# - отсутствуют значения во многих столбцах
#
# - названия столбцов привести к понятному и удобному виду (cityCenters_nearest)
#
# - некорректные типы данных (floors_total, balcony и др.)
#
# - некоторые столбцы проверить на дубликаты (locality_name)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хороший, красиво оформленный, промежуточный вывод, сразу понятно, что будет далее в предобработке.
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_center_nearest'}) #переименуем столбец cityCenters_nearest

# %%
data.isnull().sum().sort_values() #определим в каких столбцах есть пропуски
# Out:
# total_images                0
# open_plan                   0
# floor                       0
# rooms                       0
# studio                      0
# total_area                  0
# last_price                  0
# first_day_exposition        0
# locality_name              49
# floors_total               86
# living_area              1903
# kitchen_area             2278
# days_exposition          3181
# ponds_around3000         5518
# parks_around3000         5518
# city_center_nearest      5519
# airports_nearest         5542
# ceiling_height           9195
# balcony                 11519
# ponds_nearest           14589
# parks_nearest           15620
# is_apartment            20924
# dtype: int64

# %%
((data.isnull().sum()/data.shape[0])*100).round(2).sort_values() #переведем в %
# Out:
# total_images             0.00
# open_plan                0.00
# floor                    0.00
# rooms                    0.00
# studio                   0.00
# total_area               0.00
# last_price               0.00
# first_day_exposition     0.00
# locality_name            0.21
# floors_total             0.36
# living_area              8.03
# kitchen_area             9.61
# days_exposition         13.42
# ponds_around3000        23.28
# parks_around3000        23.28
# city_center_nearest     23.29
# airports_nearest        23.38
# ceiling_height          38.80
# balcony                 48.61
# ponds_nearest           61.56
# parks_nearest           65.91
# is_apartment            88.29
# dtype: float64

# %% [markdown]
# Пропущенные значения в 4 столбцах с картографическими данными и в столбце с количеством дней на публикации.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Были оценены потери, это очень важно сделать перед тем, как избавляться от данных.
#
# Можно еще посчитать процент пропущенных данных по каждому столбцу.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# В отдельной таблице посчитала долю пропущенных значений по каждому столбцу (в %).
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Хорошо, что изучено соотношение пропущенных данных, это отличная практика. 👍
#
# </div>

# %%
data['is_apartment'].unique() #проверим уникальные значения в столбце is_apartment
# Out:
# array([nan, False, True], dtype=object)

# %%
data['is_apartment'] = data['is_apartment'].fillna(0) #заменим пустые значения, значениями False, так как датафрейм содержит объекы жилой недвижимости

# %%
data['is_apartment'].isnull().sum() #проверим количество пустых значений в столбце is_apartment
# Out:
# 0

# %%
data['balcony'].unique() #проверим на унакальность столбец с количеством балконов
# Out:
# array([nan,  2.,  0.,  1.,  5.,  4.,  3.])

# %%
 data['balcony'] = data['balcony'].fillna(0) #заменим пустые значения на 0

# %%
data['balcony'].value_counts().sort_values() #проверим остались ли пустые значения
# Out:
# 3.0       81
# 4.0      183
# 5.0      304
# 2.0     3659
# 1.0     4195
# 0.0    15277
# Name: balcony, dtype: int64

# %%
data['floors_total'].unique() #проверим на унакальность столбец с этажами дома floors_total
# Out:
# array([16., 11.,  5., 14., 12., 26., 24., 27.,  9.,  6., 17., 25.,  3.,
#        23., 19., 18.,  4., 22.,  8.,  2., 10.,  7., 13., 15., nan, 20.,
#        28., 36., 21., 35., 34., 60.,  1., 29., 33., 52., 37.])

# %%
data['floors_total'] = data['floors_total'].fillna(0) #заменим пустые значения на 0

# %%
data['floors_total'].value_counts().sort_values() #проверим остались ли пустые значения
# Out:
# 34.0       1
# 33.0       1
# 29.0       1
# 37.0       1
# 52.0       1
# 60.0       1
# 36.0       3
# 28.0      21
# 35.0      24
# 1.0       25
# 0.0       86
# 26.0     124
# 21.0     158
# 27.0     164
# 11.0     203
# 13.0     229
# 20.0     271
# 22.0     286
# 19.0     339
# 23.0     352
# 15.0     365
# 2.0      383
# 8.0      390
# 24.0     469
# 18.0     505
# 14.0     553
# 7.0      592
# 3.0      668
# 17.0     833
# 6.0      914
# 25.0    1075
# 10.0    1174
# 4.0     1200
# 12.0    1362
# 16.0    1376
# 9.0     3761
# 5.0     5788
# Name: floors_total, dtype: int64

# %% [markdown]
# Проверим на уникальность столбец parks_around3000, количеством парков

# %%
data['parks_around3000'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  3.])

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0) #заменим пропущенные значения на 0

# %%
data['parks_around3000'].value_counts().sort_values() #проверим остались ли пустые значения
# Out:
# 3.0      647
# 2.0     1747
# 1.0     5681
# 0.0    15624
# Name: parks_around3000, dtype: int64

# %% [markdown]
# То же самое проделаем со столбцом ponds_around3000, количеством водоемов

# %%
data['ponds_around3000'].unique() #выведем уникальные значения, как видим пропусков нет
# Out:
# array([ 2.,  0.,  3.,  1., nan])

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(0) #заменим пропущенные значения на 0

# %%
data['ponds_around3000'].value_counts().sort_values() #проверим остались ли пустые значения, пустых значений нет
# Out:
# 3.0     1501
# 2.0     1892
# 1.0     5717
# 0.0    14589
# Name: ponds_around3000, dtype: int64

# %%
data = data.dropna(subset=['locality_name']) #удалим из датасета строки с пропущенной информацией о городе, мало количество пропущенных значений позволяет их удалить, они не представляют ценности для исследования

# %%
data['locality_name'].isna().sum() #проверим удаление пустых строк с столбце locality_name
# Out:
# 0

# %% [markdown]
# Подведем итог работы с пропущенными значениями в столбцах

# %%
data.isnull().sum().sort_values()
# Out:
# total_images                0
# ponds_around3000            0
# parks_around3000            0
# locality_name               0
# balcony                     0
# open_plan                   0
# is_apartment                0
# floor                       0
# studio                      0
# floors_total                0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# last_price                  0
# living_area              1898
# kitchen_area             2269
# days_exposition          3180
# city_center_nearest      5511
# airports_nearest         5534
# ceiling_height           9160
# ponds_nearest           14565
# parks_nearest           15586
# dtype: int64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Пропуски заполнены корректно 😃
#
# </div>

# %% [markdown]
# # Выводы
#
#
#
# - заменены значения nan на False в столбце is_apartment; по умолчанию продажа жилой недвижимости, поэтому продавцы не ставили отметку
#
# - заменены пропущенные значения в столбце floors_total
#
# - заменены пропущенные значения в столбцах parks_around3000, ponds_around3000
#
# - заменены пропущенные значения в столбце balcony на 0; если продавец не указал количество балконов в квартире, то скорее всего их нет
#
# - удалены строки с пропущеным городом locality_name; продавец при заполнении формы ошибочно пропустил этот пункт
#
# - есть проблема с картографическими данными, такими как расстояние до центра города, ближайших аэропорта, парка и водоема, заменять медианой не будем, оставим их как есть
#
# - много объявлений с пропущенной датой снятия объявления days_exposition, можно объяснить это тем, что квартиры еще не проданы

# %% [markdown]
# ### Рассмотрите типы данных в каждом столбце:<br>
# - Найдите столбцы, в которых нужно изменить тип данных.<br>
# - Преобразуйте тип данных в выбранных столбцах.<br>
# - В ячейке с типом markdown поясните, почему нужно изменить тип данных.

# %%
data.info() #рассмотрим тип данных в столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23650 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
#переведем вещественный тип данных в целый, столбцы где нет пропущенных значений
data['balcony'] = data['balcony'].astype('int64')
data['floors_total'] = data['floors_total'].astype('int64')
data['parks_around3000'] = data['parks_around3000'].astype('int64')
data['ponds_around3000'] = data['ponds_around3000'].astype('int64')
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format="%Y-%m-%dT%H:%M:%S")

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что преобразования типов все в одном месте.
#
# </div>

# %%
data.info() #проверим изменение типа данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  datetime64[ns]
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23650 non-null  int64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
# ...

# %% [markdown]
# # Выводы
#
#
# - изменены тип данных в столбцах floors_total, parks_around3000, ponds_around3000, balcony - количество этажей, дней и балконов, парков и водоёмов не может быть нецелочисленным значением
#
# - изменен тип данных в столбце first_day_exposition на тип Дата, для удобства дальнейших вычислений

# %% [markdown]
# #### 3. Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.

# %%
len(data['locality_name'].unique()) #посчитаем количество уникальных значений в столбце locality_name
# Out:
# 364

# %%
data['locality_name'] = data['locality_name'].str.lower() #приведем список к нижнему регистру

# %%
data['locality_name'] = data['locality_name'].str.replace('ё', 'е', regex=True) #заменим букву ё на е

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что тобою было замечено разное написание слова «посёлок» и было принято решение это исправить 😃
#
# </div>

# %%
data['locality_name'] = data['locality_name'].str.replace('городского типа ', '', regex=True) #удалим слова "городского типа"

# %%
data['locality_name'] = data['locality_name'].str.replace('поселок ', '', regex=True) #удалим слово "поселок"

# %%
data['locality_name'] = data['locality_name'].str.replace('деревня ', '', regex=True) #удалим слова "деревня"

# %%
data['locality_name'] = data['locality_name'].str.replace('городской ', '', regex=True) #удалим слово "городской"

# %%
data['locality_name'] = data['locality_name'].str.replace('село ', '', regex=True) #удалим слово "село"

# %%
len(data['locality_name'].unique()) #посчитаем значения снова
# Out:
# 311

# %%
data.duplicated().sum() #явных дубликатов нет
# Out:
# 0

# %% [markdown]
# Удалено 53 неявных дубликата

# %%
data['locality_name'].unique().tolist() #выведем на экран список уникальных значений населенных пунктов
# Out:
# ['санкт-петербург',
#  'шушары',
#  'янино-1',
#  'парголово',
#  'мурино',
#  'ломоносов',
#  'сертолово',
#  'петергоф',
#  'пушкин',
#  'кудрово',
#  'коммунар',
#  'колпино',
#  'красный бор',
#  'гатчина',
#  'федоровское',
#  'выборг',
#  'кронштадт',
#  'кировск',
#  'новое девяткино',
#  'металлострой',
#  'лебяжье',
#  'сиверский',
#  'молодцово',
#  'кузьмоловский',
#  'садовое товарищество новая ропша',
#  'павловск',
#  'пикколово',
#  'всеволожск',
#  'волхов',
#  'кингисепп',
#  'приозерск',
#  'сестрорецк',
#  'куттузи',
#  'аннино',
#  'ефимовский',
#  'плодовое',
#  'заклинье',
#  'торковичи',
#  'первомайское',
#  'красное село',
#  'понтонный',
#  'сясьстрой',
#  'старая',
#  'лесколово',
#  'новый свет',
#  'сланцы',
#  'путилово',
#  'ивангород',
#  'шлиссельбург',
#  'никольское',
#  'зеленогорск',
#  'сосновый бор',
#  'оржицы',
#  'кальтино',
#  'романовка',
#  'бугры',
#  'рощино',
#  'кириши',
#  'луга',
#  'волосово',
#  'отрадное',
#  'павлово',
# ...

# %% [markdown]
# #### 4. Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.
#
# - Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение.
# - В противном случае удалите редкие и выбивающиеся значения.
# - В ячейке с типом markdown опишите, какие особенности в данных вы обнаружили.

# %%
data.describe() #методом describe посмотрим на максимальные и минимальные значения в датасете
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23650.000000  2.365000e+04  23650.000000  23650.000000    14490.000000
# mean       9.862326  6.541127e+06     60.329069      2.070106        2.771287
# std        5.682278  1.089640e+07     35.661808      1.078620        1.261593
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.799000e+06     69.700000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23650.000000  21752.000000  23650.000000  21381.000000  23650.000000
# mean      10.637505     34.448356      5.893277     10.566403      0.591712
# ...

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8            0   False
# 1             NaN            11         18.6      1            0   False
# 2             NaN             5         34.3      4            0   False
# 3             NaN            14          NaN      9            0   False
# 4            3.03            14         32.0     13            0   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Привлекают внимание столбцы ceiling_height, living_area, kitchen_area.
# Рассчитаем медианы, чтобы заполнить пустые значения в столбцах.

# %%
data['ceiling_height'].median() #медиана для ceiling_height
# Out:
# 2.65

# %%
data['living_area'].median() #медиана для living_area
# Out:
# 30.0

# %%
data['kitchen_area'].median() #медиана для kitchen_area
# Out:
# 9.1

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.65) #заменим пустые значения в столбце ceiling_height на медианные

# %%
data['ceiling_height'].value_counts()
# Out:
# 2.65     9836
# 2.50     3515
# 2.60     1645
# 2.70     1572
# 3.00     1109
#          ...
# 4.25        1
# 3.39        1
# 3.93        1
# 10.30       1
# 4.65        1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
data['living_area'] = data['living_area'].fillna(30.0) #заменим пустые значения в столбце living_height на медианные

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(9.1) #заменим пустые значения в столбце kitchen_height на медианные

# %%
data.isnull().sum().sort_values() #проверим наличие пустых значений
# Out:
# total_images                0
# ponds_around3000            0
# parks_around3000            0
# locality_name               0
# balcony                     0
# kitchen_area                0
# open_plan                   0
# is_apartment                0
# studio                      0
# living_area                 0
# floors_total                0
# ceiling_height              0
# rooms                       0
# first_day_exposition        0
# total_area                  0
# last_price                  0
# floor                       0
# days_exposition          3180
# city_center_nearest      5511
# airports_nearest         5534
# ponds_nearest           14565
# parks_nearest           15586
# dtype: int64

# %%
data['ceiling_height'].unique() #исследуем на аномалии столбец ceiling_height высота потолка
# Out:
# array([  2.7 ,   2.65,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   3.2 ,   2.61,   3.25,
#          3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,   3.3 ,
#          2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,   3.4 ,
#          3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,   2.58,
#          3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,   2.45,
#          3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,   3.16,
#          3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,   5.  ,
#          2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,   2.83,
#          4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,   3.18,
#          3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,   2.63,
#          3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,   3.66,
#          3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,   3.36,
# ...

# %%
data.boxplot(column='ceiling_height', figsize=(15,10)); #проверим аномальные значения на диаграмме размаха
plt.ylim(0,120)
# Out:
# (0.0, 120.0)

# %%
#заменим некорректные значения, внесенные продавцом, такие как 24 метра, 25 метров и т.д.
data['cieling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 24.0, data['ceiling_height'] == 2.4)                       
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 25.0, data['ceiling_height'] == 2.5)                       
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 26.0, data['ceiling_height'] == 2.6)                       
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 27.0, data['ceiling_height'] == 2.7)                       
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 32.0, data['ceiling_height'] == 3.2)                       
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 20.0, data['ceiling_height'] == 2.0)
data['ceiling_height'] = data['ceiling_height'].where(data['ceiling_height'] != 27.5, data['ceiling_height'] == 2.75)

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid Gold">
# <h5> ⚠️ <font color="DarkGoldenRod">Комментарий ревьюера (желтый)</font></h5>
#
# Выше у тебя [харкод](https://en.wikipedia.org/wiki/Hard_coding), то есть ты прописываешь руками числа, а не ссылаешься на значения из таблицы.
#
# Поясню, харкод, это когда ты подставляешь какие-то значения в код руками, а не вычисляешь методами из данных. В данном случае — это плохо, ведь если тебе дать аналогичные по структуре данные, то будут не верные построения и вычисления. Харкод не всегда плохо, например в играх получилось сделать прорыв в графике благодаря числу в коде, которое упрощает вычисления, можешь почитать в [статье](https://thecode.media/quake-root/).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Ознакомлюсь со статьей чуть позже, постараюсь разобраться как сделать код оптимальней. Валентин, срасибо за полезную инормацию.
# </div>

# %%
data = data.query('2 < ceiling_height < 4')  #отфильтуем строки менее 2 метров и более 4 метров, так как эти значения не реалистичные

# %%
data['ceiling_height'].unique() #проверим высоту потолка на уникальные значения методом unique
# Out:
# array([2.7, 2.65, 3.03, 2.5, 2.67, 2.56, 3.05, 2.75, 2.6, 2.9, 2.8, 2.55,
#        3.0, 3.2, 2.61, 3.25, 3.45, 2.77, 2.85, 2.64, 2.57, 3.5, 3.3, 2.71,
#        2.47, 2.73, 2.84, 3.1, 2.34, 3.4, 3.06, 2.72, 2.54, 2.51, 2.78,
#        2.76, 2.58, 3.7, 2.52, 2.87, 2.66, 2.59, 2.45, 3.6, 2.92, 3.11,
#        3.13, 3.8, 3.15, 3.55, 3.16, 3.62, 3.12, 2.53, 2.74, 2.96, 2.46,
#        2.79, 2.95, 2.94, 3.82, 3.54, 3.53, 2.83, 2.4, 3.38, 3.01, 3.65,
#        3.9, 3.18, 3.35, 2.3, 3.57, 2.48, 2.62, 2.82, 3.98, 2.63, 3.83,
#        3.52, 3.95, 3.75, 2.88, 3.67, 3.87, 3.66, 3.85, 3.86, 3.24, 3.36,
#        3.08, 3.68, 3.07, 3.37, 3.09, 3.26, 3.34, 2.81, 3.44, 2.97, 3.14,
#        2.68, 3.22, 3.27, 2.93, 3.46, 3.47, 3.33, 3.63, 3.32, 2.98, 2.86,
#        3.17, 3.28, 3.04, 3.84, 3.23, 3.02, 3.21, 3.43, 3.78, 3.39, 2.69,
#        3.31, 3.56, 2.2, 3.51, 3.93, 3.42, 2.99, 3.49, 2.91, 3.88, 3.29,
#        2.25, 3.76, 3.69, 2.89, 3.58, 2.49, 3.48, 3.59], dtype=object)

# %%
data['ceiling_height'].describe() #выведем общую информацию по ceiling_height
# Out:
# count     23523.00
# unique      142.00
# top           2.65
# freq       9836.00
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins=20) #построим гистограмму на 20 корзин
# Out:
# <AxesSubplot:>

# %%
data['living_area'].describe() #проверим на аномальные значения столбец living_area, жилая площадь
# Out:
# count    23523.000000
# mean        33.933139
# std         20.660933
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         41.000000
# max        409.700000
# Name: living_area, dtype: float64

# %%
data.boxplot(column='living_area', figsize=(15,10)) #посторим диаграмму размаха для living_area
plt.ylim(0, 420)
# Out:
# (0.0, 420.0)

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Рад, что ты используешь ylim, так понятнее.
#
# </div>

# %% [markdown]
# На диаграмме размаха видно что присутствуют аномально меленькие и большие значения менее 10 и более 250

# %%
data = data.query('10 < living_area < 250') #удалим строки со значениями меньше 10 и более 250

# %%
data['living_area'].hist(bins=20) #построим гистограмму на 20 корзин
# Out:
# <AxesSubplot:>

# %% [markdown]
# Исследуем на аномалии столбец kitchen_area

# %%
data['kitchen_area'].describe() #минимальная площадь 1,3 кв.м, максимальная 107 кв.м
# Out:
# count    23450.000000
# mean        10.369314
# std          5.439856
# min          1.300000
# 25%          7.300000
# 50%          9.100000
# 75%         11.400000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %%
data.boxplot(column='kitchen_area', figsize=(15,10)) #построим диаграмму размаха для kitchen_area
plt.ylim(0, 110)
# Out:
# (0.0, 110.0)

# %%
count_data = data.shape[0] #перед удалением строк посчитаем объем датасета
count_data
# Out:
# 23450

# %%
data = data.query('4 < kitchen_area < 80') #избавимся от строк с площадью кухни менее 4 кв.м и более 80 кв.м

# %%
count_data_new =data.shape[0] #после удаления строк, снова посчитаем объем датасета
count_data_new
# Out:
# 23391

# %%
print(count_data_new/count_data*100) #найдем % оставшихся строк
# Out:
# 99.74840085287846

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Перед отбросом выбросов очень важно в процентах оценить, сколько мы теряем, должно быть не более 10%.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Валентин, добавила расчет %, теряем менее 1% данных. Можем продолжать исследование.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Верное исправление 👍
#
# На самом деле чем больше данных остается, тем лучше, поэтому лучше убирать именно выбивающиеся значения, если их много, то значит у нас данные размазаны, а эти значения нормальные(а не выбивающиеся).
#
# Я в работе пользуюсь методом [quantile](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html) и убираю с обеих сторон данные, которые выходят за 1-3%(то есть менее 0.03 и более 0.97 перцентиля), если сделать такое преобразование по нескольким колонкам, то как раз и получится около 10%. Ниже показал.
#
# </div>

# %%
# Код ревьюера

low_percentele = 0.01
hihg_percentele = 0.99

last_price_low = data['last_price'].quantile(low_percentele)
last_price_high = data['last_price'].quantile(hihg_percentele)

print(f'Нижняя граница last_price {last_price_low}')
print(f'Нижняя граница last_price {last_price_high}')

print(
    'Процент отброшенных значений = ',
    round(
        100 - len(data.query('@last_price_low <= last_price <= @last_price_high'))
        / len(data['last_price']) * 100,
        2
    ),
    '%'
)
# Out:
# Нижняя граница last_price 1000000.0
# Нижняя граница last_price 33529999.999999564
# Процент отброшенных значений =  1.95 %

# %%
data['kitchen_area'].value_counts() #посчитаем уникальные значения в столбце kitchen_area
# Out:
# 9.10     2316
# 6.00     1293
# 10.00    1247
# 8.00     1100
# 9.00     1092
#          ...
# 14.74       1
# 53.10       1
# 13.41       1
# 34.51       1
# 16.74       1
# Name: kitchen_area, Length: 941, dtype: int64

# %%
data['kitchen_area'].hist(bins=20) #посторим гистограмму по столбцу kitchen_area
# Out:
# <AxesSubplot:>

# %% [markdown]
# Исследуем аномалии в столбце rooms

# %%
data['rooms'].describe() #посмотрим на общую информацию по столбцу rooms, присутствует значение 0 и более 10
# Out:
# count    23391.000000
# mean         2.066179
# std          1.058720
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         16.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].unique() #исследуем уникальные значения
# Out:
# array([ 3,  1,  2,  4,  5,  6,  0,  7, 11,  8, 14, 10,  9, 16])

# %%
data = data.query('1 <= rooms <= 10') #удалим строки, где число комнат = 0 и более 10

# %%
data['rooms'].hist(bins=20) #посторим гистограмму по столбцу rooms
# Out:
# <AxesSubplot:>

# %% [markdown]
# Исследуем на аномалии столбец floors_total

# %%
data['floors_total'].unique()
# Out:
# array([16, 11,  5, 14, 12, 26, 24, 27,  9,  6, 17, 25,  3, 23, 19, 18,  4,
#        22,  8,  2, 10,  7, 13, 15,  0, 20, 28, 36, 21, 35, 34, 60,  1, 29,
#        33, 52])

# %% [markdown]
# Аномальных значений с столбце floors_total нет.

# %%
data['total_images'].unique() #проверим на аномалии столбец total_images
# Out:
# array([20,  7, 10,  0,  2,  6,  5, 18,  9,  1, 16, 11,  8, 12, 13,  3, 15,
#        17, 14, 19, 32,  4, 35, 39, 23, 21, 27, 30, 24, 25, 28, 31, 22, 29,
#        26, 50, 42, 37])

# %% [markdown]
# Аномальных значений нет

# %%
print(data['last_price'].min()) #проверим на аномалии столбец с ценой квартиры last_price
print(data['last_price'].max())
print(data['last_price'].mean())
# Out:
# 12190.0
# 401300000.0
# 6391306.422436837

# %%
data.boxplot(column='last_price', figsize=(15,10)) #построим диаграмму размаха для last_price
plt.ylim(0, 402000000)
# Out:
# (0.0, 402000000.0)

# %% [markdown]
# Минимальная стоимсть квартиры в 12 тыс рублей кажется не реальной, узнаем сколько квартир менее стоимости 500 тыс руб

# %%
data.query('last_price < 500000').count() #14 квартир менее 500 тыс руб, можно пренебречь этими данными
# Out:
# total_images            14
# last_price              14
# total_area              14
# first_day_exposition    14
# rooms                   14
# ceiling_height          14
# floors_total            14
# living_area             14
# floor                   14
# is_apartment            14
# studio                  14
# open_plan               14
# kitchen_area            14
# balcony                 14
# locality_name           14
# airports_nearest         1
# city_center_nearest      1
# parks_around3000        14
# parks_nearest            1
# ponds_around3000        14
# ponds_nearest            0
# days_exposition         13
# cieling_height          14
# dtype: int64

# %%
data = data.loc[data['last_price'] > 500000] #удалим строки

# %%
data['last_price'].hist(bins=30) #посторим гистограмму по столбцу last_price
# Out:
# <AxesSubplot:>

# %% [markdown]
# Проверим на аномалии столбец airports_nearest

# %%
print(data['airports_nearest'].min()) #проверим на аномалии
print(data['airports_nearest'].max())
print(data['airports_nearest'].mean())
# Out:
# 0.0
# 84869.0
# 28838.094956991063

# %%
data.query('airports_nearest < 1000 ') #проверим сколько квартир расположены в непосредственной близости от аэропорта до 1000 м
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 21085            2.7             9         19.8      3            0   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 21085      False           6.0        2  санкт-петербург               0.0
#
#        city_center_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21085              22801.0                 0            NaN                 0
#
#        ponds_nearest  days_exposition cieling_height
# 21085            NaN             60.0            2.7

# %% [markdown]
# Всего 1 строка, удалим ее из выборки.

# %%
data = data.loc[data['airports_nearest'] != 0] #удалим строку где расстояние до аэропорта 0 м

# %%
data['airports_nearest'].describe() #проверка удаления строки
# Out:
# count    17786.000000
# mean     28839.716350
# std      12646.346008
# min       6450.000000
# 25%      18551.250000
# 50%      26812.000000
# 75%      37364.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
data['city_center_nearest'].describe() #проверим аномалии в столбце city_center_nearest, аномалий нет
# Out:
# count    17806.000000
# mean     14245.556722
# std       8604.005893
# min        181.000000
# 25%       9356.000000
# 50%      13135.500000
# 75%      16298.000000
# max      65968.000000
# Name: city_center_nearest, dtype: float64

# %%
data['ponds_nearest'].describe() #проверим аномалии в столбце ponds_nearest
# Out:
# count    8875.000000
# mean      518.787380
# std       277.608305
# min        13.000000
# 25%       294.000000
# 50%       503.000000
# 75%       731.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# Аномальных значенй нет, дом может находится на берегу реки или озера.

# %%
data['parks_nearest'].describe() #проверим аномалии в столбце parks_nearest
# Out:
# count    7913.000000
# mean      490.815620
# std       343.014591
# min         1.000000
# 25%       288.000000
# 50%       453.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Аномалий также нет, так как дом может находится в парке или лесу.

# %% [markdown]
# ##### Выводы:
# закончена предобработка данных.
# Заменены пропущенные значения(не все), изменены типы данных, заменены явные и неявные дубликаты, устранены редкие и выбивающиеся значения.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, проведено мини исследование, пропуски заполнены с минимальными потерями в информации 👍
#
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы
# - цена одного квадратного метра;
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).

# %%
data['price_1m'] = (data['last_price']/data['total_area']).round(2) #создание столбца с ценой 1 кв метра

# %%
data['publishing_day'] = data['first_day_exposition'].dt.weekday #столбец с днем публикации

# %%
data['publishing_month'] = data['first_day_exposition'].dt.month #столбец с месяцем публикации

# %%
data['publishing_year'] = data['first_day_exposition'].dt.year #столбец с годом публикации

# %%
def floor_number(row):  #напишем функцию для категоризации этажа квартиры, добавление столбца floor_number
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    return 'другой'

data['floor_number'] = data.apply(floor_number, axis=1) #вызовем функцию

# %%
data['floor_number'].value_counts() #проверим значения в новом столбце
# Out:
# другой       17068
# последний     3257
# первый        2850
# Name: floor_number, dtype: int64

# %%
data['city_center_nearest'] = (data['city_center_nearest']/1000).round(0) #переведем расстояние до центра города в км и округлим до целого

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, корректно созданы дополнительные столбцы с необходимыми метриками.
#
# </div>

# %%
data.head(10) #проверим добавление столбцов
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#   ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.7            16        51.00      8            0   False
# 1           2.65            11        18.60      1            0   False
# ...

# %% [markdown]
# ### Выводы:
# Все необходимые столбцы добавлены. Можно приступать к исследовательскому анализу данных.

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучите следующие параметры объектов:
#
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день и месяц публикации объявления.
#
#
# Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %%
data['total_area'].hist(bins=25) #построим гистограмму для total_area общей площади квартиры
# Out:
# <AxesSubplot:>

# %% [markdown]
# Можно ограничить площадь 200 кв.м, чтобы посмотреть подробнее.

# %%
data.query('total_area < 200')['total_area'].hist(bins=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большинство общей площади квартир находится в диапозоне от 37 до 50 кв.м, что логично.

# %%
data['living_area'].hist(bins=25) #построим гистограмму для living_area, жилой площади квартиры
# Out:
# <AxesSubplot:>

# %% [markdown]
# Здесь наблюдается 2 пика.

# %%
data.query('kitchen_area < 50')['kitchen_area'].hist(bins=25) #построим гистограмму для kitchen_area, площади кухни, ограничим площадь кухни 50 кв.м.
# Out:
# <AxesSubplot:>

# %% [markdown]
# Наблюдается пик с площадью кухни в 9 кв.м

# %%
data['last_price'].hist(bins=50) #построим гистограмму для цены квартиры last_price
# Out:
# <AxesSubplot:>

# %%
data.query('last_price < 50000000')['last_price'].hist(bins=35) #ограничим макисмальную цену в 50 млн руб, чтобы увидеть распределение
# Out:
# <AxesSubplot:>

# %% [markdown]
# Получили гистограмму с нормальным распределением

# %%
data['rooms'].describe()
# Out:
# count    23175.000000
# mean         2.081467
# std          1.033240
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         10.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].hist() #построим гистограмму,  чтобы увидеть распределение по количеству комнат в квартире, ограничим 10 комнатами
# Out:
# <AxesSubplot:>

# %% [markdown]
# Можно сказать что 75% квартир с 1, 2 или 3 комнатами

# %%
data.query('ceiling_height < 4')['ceiling_height'].hist() #ограничим высоту потолков до 4 м и посмотрим на распределение
# Out:
# <AxesSubplot:>

# %% [markdown]
# По гистограмме можно сделать вывод, что стандартная высота потолков 2,6 - 2,7  м

# %%
data['floor'].hist(bins=30) #посмотрим на распределение квартир по этажам
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая доля квартир в продаже, находятся на первом этаже. Видимо спрос на квартиры на первом этаже небольшой, поэтому предложений так много. Чем выше этаж, тем меньше предложений о продаже.

# %%
data['floor_number'].hist() #посмотри на распределение квртир по типам этажей "первый", "последний", "другой"
# Out:
# <AxesSubplot:>

# %% [markdown]
# Квартир в продаже на последнем этаже, почти такое же количество, как и на первом.

# %%
data['floors_total'].hist() #посмотрим на этажность домов
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пик приходится на первые 5 этажей, болшьше всего квартир продается в малоэтажных домах.

# %%
data['city_center_nearest'].hist(bins=40) #посмотрим на распределение километража до центра города
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме есть несколько пиков, большинство квартир находятся на расстоянии в от 5 до 20 км от центра города.

# %%
data['airports_nearest'].hist(bins=20) #посмотрим на расстояние до аэропорта
# Out:
# <AxesSubplot:>

# %% [markdown]
# Распределение нормальное. Большинство квартир находится на растоянии в 40 км до аэропорта.

# %%
data['parks_nearest'].hist(bins=20) #построим гистограмму расстояния до ближайшего парка
# Out:
# <AxesSubplot:>

# %% [markdown]
# В большинстве случаев, парк находится рядом с продаваемой квартирой, в радиусе 1 км.

# %%
data['publishing_day'].hist(bins=7) #посторим гистограмму на 7 корзин, 7 дней недели
# Out:
# <AxesSubplot:>

# %% [markdown]
# Меньше всего объявлений продавцы публиковали в выходные (субботу и воскресенье). Возможно, что большая доля объявлений приходится на агентства, которые не работаю в выходные.

# %%
data['publishing_month'].hist(bins=12) #построим гистограмму на 12 корзин, чтобы увидеть распределение по месяцам
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего объявлений публикуется в феврале, марте, апреле и сентябре, октябре и ноябре. Четко виден трен на спад летом.

# %% [markdown]
# ####  Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"

# %%
data['days_exposition'].hist(bins=50) #построим гистограмму по столбцу days_exposition
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видно, что большинство квартир продается в первые 200 дней после публикации. Чем дольше объявление висит на сайте, тем меньше шансов на продажу. Посмотрим на гистограмму за год, то есть отфильтруем таблицу до 365 дней.

# %%
data.query('days_exposition < 365')['days_exposition'].hist(bins=50) #построим гистограмму на 365 дней
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме видны 2 пика. Посмотрим на пиковые значения более детально.

# %%
data['days_exposition'].hist(bins=50, range=(0,100), figsize=(15,5)); #зададим значение оси х - 100 дней

# %% [markdown]
# Сейчас можем видеть что больше всего объявлений висело 45 и 60 дней, возможно было ограничение по сроку публикации на самом сайте. Также есть небольшой пик в районе 90 дней, возможно это предоплаченные объявления на 90 дней без пролонгации.

# %%
data['days_exposition'].describe() #посмотрим на характеристики методом describe
# Out:
# count    20056.000000
# mean       181.126446
# std        219.869373
# min          1.000000
# 25%         45.000000
# 50%         96.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Молодец, верно интерпретированы данные из графика и .describe() 😃
#
# </div>

# %% [markdown]
# Среднее: 181,12
# Медиана: 96

# %% [markdown]
# 75% квартир продается в первые 232 дня после публикации (можем сказать, что это быстрая продажа). Также есть и долгие, максимальное значение дней - 1580.

# %% [markdown]
# #### "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#   - общей площади;
#   - жилой площади;
#   - площади кухни;
#   - количество комнат;
#   - типа этажа, на котором расположена квартира (первый, последний, другой);
#   - даты размещения (день недели, месяц, год);

# %% [markdown]
# Построим сводную таблицу, с медианным значением общей площади квартиры

# %%
total_area_pivot = data.pivot_table(index='last_price', values='total_area', aggfunc='median')
print(total_area_pivot)
# Out:
#              total_area
# last_price
# 520000.0           30.0
# 530000.0           29.6
# 550000.0           36.0
# 560000.0           32.0
# 565000.0           45.0
# ...                 ...
# 240000000.0       410.0
# 245000000.0       285.7
# 289238400.0       187.5
# 330000000.0       190.0
# 401300000.0       401.0
#
# [2907 rows x 1 columns]

# %%
data.plot(style='o', y='last_price', x='total_area', grid=True, figsize=(25,10), alpha = 0.3) #построим график зависимости last_price от total_area)
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# 1. Обрати внимание на то, что на данном графике все точки слились в большое пятно.
#
#     Повтори, пожалуйста, еще раз в спринт «Исследовательский анализ данных» тему «Взаимосвязь данных» урок «Корреляция» и попробуй добавить параметр прозрачности.
#
#     Поправь, пожалуйста, тут и на всех подобных графиках ниже.
#
# 2. Нужно строить на изначальных данных, а не на аггрегированных.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Перестроила график, используя неагрегированные данные и добавила параметр alpha=0,3.
# <br>
# Эти же действия применила к графикам ниже.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ График построен верно, спасибо, что добавлена прозрачность, так нагляднее. 👍
#
# </div>

# %%
print(data['last_price'].corr(data['total_area'])) #рассчитаем коэффициент корреляции
# Out:
# 0.6759521132933423

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Полный вывод, правильно посчитана и интерпретирована корреляция.
#
# </div>

# %% [markdown]
# На графике наблюдаем хвост вверх и вправо, т.е. зависимость цены от общей площади квартиры есть, но она не слишком выражена. Это подтверждает коэффициент корреляции - 0,67.

# %%
living_area_pivot = data.pivot_table(index='last_price', values='living_area', aggfunc='median') #построим таблицу зависимости last_price от living_area)
print(living_area_pivot)
# Out:
#              living_area
# last_price
# 520000.0            18.0
# 530000.0            16.0
# 550000.0            20.0
# 560000.0            17.2
# 565000.0            25.0
# ...                  ...
# 240000000.0        218.0
# 245000000.0        182.8
# 289238400.0         63.7
# 330000000.0         95.0
# 401300000.0        204.0
#
# [2907 rows x 1 columns]

# %%
data.plot(y='last_price', x='living_area', style='o', grid=True, figsize=(25,10), alpha = 0.3) #построим график зависимости last_price от living_area)
# Out:
# <AxesSubplot:xlabel='living_area'>

# %%
print(data['last_price'].corr(data['living_area'])) #рассчитаем коэффициент корреляции
# Out:
# 0.536567957052617

# %% [markdown]
# Коэффициент 0,53 говорит о наличии связи, однако не слишком сильной.

# %%
kitchen_area_pivot = data.pivot_table(index='last_price', values='kitchen_area', aggfunc='median') #построим график зависимости last_price от kitchen_area)
print(kitchen_area_pivot)
# Out:
#              kitchen_area
# last_price
# 520000.0              5.5
# 530000.0              5.8
# 550000.0              7.5
# 560000.0              6.0
# 565000.0              9.0
# ...                   ...
# 240000000.0          40.0
# 245000000.0          29.8
# 289238400.0          30.2
# 330000000.0          40.0
# 401300000.0          24.0
#
# [2907 rows x 1 columns]

# %%
data.plot(y='last_price', x='kitchen_area', style='o', grid=True, figsize=(25,10), alpha = 0.3) #построим график зависимости last_price от kitchen_area)
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %%
print(data['last_price'].corr(data['kitchen_area'])) #рассчитаем коэффициент корреляции
# Out:
# 0.46069961850845165

# %% [markdown]
# Коэффициент корреляции = 0,46, есть совсем небольшая связь между ценой и площадью кухни.

# %%
rooms_area_pivot = data.pivot_table(index='last_price', values='rooms', aggfunc='median') #построим таблицу зависимости last_price от rooms)
print(rooms_area_pivot)
# Out:
#              rooms
# last_price
# 520000.0       1.0
# 530000.0       1.0
# 550000.0       1.0
# 560000.0       1.0
# 565000.0       2.0
# ...            ...
# 240000000.0    6.0
# 245000000.0    6.0
# 289238400.0    2.0
# 330000000.0    3.0
# 401300000.0    5.0
#
# [2907 rows x 1 columns]

# %%
data.plot(y='last_price', x='rooms', style='o', grid=True, figsize=(25,10), alpha = 0.3) #построим график зависимости last_price от rooms)
# Out:
# <AxesSubplot:xlabel='rooms'>

# %%
print(data['last_price'].corr(data['rooms'])) #рассчитаем коэффициент корреляции
# Out:
# 0.3832626708263356

# %% [markdown]
# Взаимосвязи между ценой квартиры и количеством комнат практически нет. Дорогими бывают как двухкомнатные, так и семикомнатные квартиры.

# %%
floor_pivot = data.pivot_table(index='floor_number', values='last_price', aggfunc='median') #построим таблицу зависимости last_price от floor_number)
print(floor_pivot)
# Out:
#               last_price
# floor_number
# другой         4862500.0
# первый         3900000.0
# последний      4300000.0

# %%
data.boxplot(column=['last_price'], by='floor_number', figsize=(8,6)) #построим график зависимости last_price от floor_number)
# Out:
# <AxesSubplot:title={'center':'last_price'}, xlabel='floor_number'>

# %% [markdown]
# Самыми дешевыми квартирами являются квартиры на первом этаже.

# %%
data.boxplot(column=['last_price'], by='publishing_day', figsize=(8,6)) #построим график зависимости цены от дня недели
plt.suptitle('Распределение цен по дням недели') #присвоим название графику
plt.title('') 
plt.ylim(0, 12500000) #ограничим по оси y значением 12500000
plt.xlabel('День недели') #название оси x
plt.ylabel('Цена') #название оси y
plt.show() #выведем на экран

# %%
data.boxplot(column=['last_price'], by='publishing_month', figsize=(12,6)) #построим график зависимости цены от месяца
plt.suptitle('Распределение цен по месяцам') #присвоим название графику
plt.title('')
plt.ylim(0, 12500000) #ограничим по оси y значением 12500000
plt.xlabel('Месяц') #название оси x
plt.ylabel('Цена') #название оси y
plt.show() #выведем на экран

# %%
data.boxplot(column=['last_price'], by='publishing_year', figsize=(10,8)) #построим график зависимости цены от года
plt.suptitle('Распределение цен по годам') #присвоим название графику
plt.title('')
plt.ylim(0, 15000000) #ограничим по оси y значением 15000000
plt.xlabel('Год') #название оси x
plt.ylabel('Цена') #название оси y
plt.show() #выведем на экран

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Красивое построение и выводы правильные, молодец 😃
#
# </div>

# %% [markdown]
# По трем графикам можно сделать вывод, что цена квартиры не зависит от дня недели и месяца публикации, но есть взаимосвязь между ценой и годом. В 2014 году медиана цены была выше, на уровне 750 тыс руб, в остальные годы на уровне 500 тыс руб. В 2014 году 75% квартир стоило до 1,4 млн руб, а после сильно меньше, в районе 700-800 тыс. руб.

# %% [markdown]
#  #### "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name."

# %%
top_10_city = data.pivot_table(index='locality_name', values='price_1m', aggfunc=['count', 'mean']) #построим сводную таблицу
top_10_city.columns = ['count', 'mean'] # переименуем столбцы
top_10_city = top_10_city.sort_values(by='count', ascending=False).head(10) #отсортируем таблицу по столбцу count
top_10_city['mean'] = top_10_city['mean'].astype(int) #изменим тип данных на int
top_10_city_mean = top_10_city.sort_values(by='mean', ascending=False).head(10) #отсортируем таблицу по столбцу mean
print(top_10_city)
# Out:
#                  count    mean
# locality_name
# санкт-петербург  15415  114054
# мурино             554   85245
# кудрово            449   95151
# шушары             433   78264
# всеволожск         389   68579
# пушкин             365  102728
# колпино            338   75424
# парголово          323   90289
# гатчина            305   68811
# выборг             231   58251

# %%
top_10_city_mean.plot(kind = 'bar', y = 'mean')
plt.suptitle('ТОП-10 городов по цене за 1 кв.м') #присвоим название графику
plt.xlabel('Город') #название оси x
plt.ylabel('Цена за кв.метр') #название оси y
plt.show() #выведем на экран

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Построй, пожалуйста, столбчатую диаграмму или ящики с усами стоимости квадратного метра по топ 10 населенным пунктам.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Построила гистограмму на основе вновь созданной переменной top_10_city_mean (сортировка по убыванию значения средней стоимости квадратного метра.)
# <br>
# Сохранила сортировку в сводной таблице по количеству объявлений.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Спасибо за интересные наблюдения 😃
#
# </div>

# %% [markdown]
# Самая высокая стоимость квадратного метра в Санкт-Петербурге - 114054 рубля, самая низкая в Выборге - 58251 рубль.

# %% [markdown]
# #### "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."

# %%
city_data = data.query('locality_name == "санкт-петербург"') # отфильтруем таблицу по городу Санкт-Петербург

# %%
center_km_mean = city_data.pivot_table(index='city_center_nearest', values='last_price', aggfunc=['count', 'mean']) #построим сводную по расстоянию от центра и цены

# %%
center_km_mean['mean'] = center_km_mean['mean'].astype(int) #определим тип данных в столбце mean как int

# %%
center_km_mean.columns = ['count', 'mean'] #переименуем столбцы
print(center_km_mean) # выведем на экран таблицу
# Out:
#                      count      mean
# city_center_nearest
# 0.0                     24  32053401
# 1.0                    180  20571946
# 2.0                    295  17278207
# 3.0                    337  10837116
# 4.0                    667  11828580
# 5.0                    892  13635039
# 6.0                    595  14308821
# 7.0                    410  14398105
# 8.0                    584   9300576
# 9.0                    584   6955426
# 10.0                   709   6529790
# 11.0                  1169   6248913
# 12.0                  1586   5857585
# 13.0                  1430   6128963
# 14.0                  1256   5662150
# 15.0                  1555   5890702
# 16.0                  1246   5389358
# 17.0                   867   5330385
# 18.0                   260   5099374
# 19.0                   153   5059640
# 20.0                    45   6051817
# 21.0                   115   5515375
# 22.0                   202   5415524
# 23.0                    82   5018987
# ...

# %%
center_km_mean['mean'].plot() #построим график зависимости цены от расстояния до центра
plt.suptitle('Зависимость цены квартиры от расстояния до ценра СПБ') #присвоим название графику
plt.xlabel('Расстояние до центра СПБ') #название оси x
plt.ylabel('Цена квартиры') #название оси y
plt.show() #выведем на экран

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# Построй, пожалуйста, график зависимости средней стоимости объектов от км до центра города в Санкт-Петербурге. Необходимо для каждого километра посчитать среднюю стоимость объекта, и по ним построить график.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Построила график зависимости цены квартиры от расстояния до центра города на основе ранее построенной сводной таблицы.
# <br>
# Обновила вывод.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Супер, корректно выделены квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислена средняя цена каждого километра. 👍
#
# </div>

# %% [markdown]
# С ростом удаленности от центра цена квартиры уменьшается. Самая высокая стоимость квартир в радиусе до 2-3 км. Есть пик в районе 27 км, возможно это район новостроек с более дорогой ценой.

# %% [markdown]
# ### Общий вывод
#
# В качестве исходных данных была получена информация о продаже картир в городе Санкт-Петербург и области с сайта недвижимости.
#
# #### Была проведена предобработка данных:
# - найдены и обработаны пропущенные значения в столбцах floors_total, parks_around3000, ponds_around3000, balcony
# - переименован столбец cityCenters_nearest в city_center_nearest
# - изменены типы данных в столбцах floors_total, parks_around3000, ponds_around3000, balcony, first_day_exposition
# - обработаны неявные дубликаты в столбце locality_name
# - удалены строки с пропусками в столбце locality_name
# - проанализированы выбросы (минимальные и максимальные значения по каждому столбцу)
#
#
# #### Проведен исследовательский анализ данных:
# - добавлены новые столбцы с ценой за квадратный метр, день недели, месяц, год публикации, категория этажа квартиры (первый, поледний, другой) и расстояние до центра города в километрах
# - построены гистограммы для каждого параметра с целью изучения каждого.
#
# ###### Основные выводы:
#
# - большинство общей площади квартир находится в диапозоне от 37 до 50 кв.м
# - большинство квартир имеют кухню 9 кв.м
# - 75% квартир с 1, 2 или 3 комнатами
# - стандартная высота потолков 2,6 - 2,7 м
# - большая доля квартир в продаже, находятся на первом этаже. Видимо спрос на квартиры на первом этаже небольшой, поэтому предложений так много. Чем выше этаж, тем меньше предложений о продаже
# - квартир в продаже на последнем этаже, почти такое же количество, как и на первом
# - болшьше всего квартир продается в с 1 по 5 этажи
# - большинство квартир находятся на расстоянии в от 5 до 20 км от центра города
# - большинство квартир находится на растоянии в 40 км до аэропорта
# - в большинстве продаваемых квартир, парк находится рядом, в радиусе 1 км
# - меньше всего объявлений продавцы публиковали в выходные (субботу и воскресенье). Возможно, что большая доля объявлений приходится на агентства, которые не работают в выходные
# - больше всего объявлений публикуется в феврале, марте, апреле и сентябре, октябре и ноябре. Четко виден тренд на спад летом.
#
#
# ###### Как быстро продавались квартиры
# - 75% квартир продается в первые 200 дней после публикации (можем сказать, что это быстрая продажа)
# - также есть и долгие, максимальное значение дней - 1580.
# - чем дольше объявление висит на сайте, тем меньше шансов на продажу.
# - больше всего объявлений висело 45 и 60 дней, возможно было ограничение по сроку публикации на самом сайте
# - также есть небольшой пик в районе 90 дней, возможно это предоплаченные объявления на 90 дней без пролонгации
#
# ###### Какие факторы влияют на полную стоимость квартиры
# - зависимость цены от общей площади квартиры есть, но она не слишком выражена. Это подтверждает коэффициент корреляции - 0,67
# - самыми дешевыми квартирами являются квартиры на первом этаже
# - также цена квартиры мало зависит от жилой площади, площади кухни и количества комнат
# - цена квартиры не зависит от дня недели и месяца публикации, но есть взаимосвязь между ценой и годом продажи
# - в 2014 году медиана цены была выше, на уровне 750 тыс руб, в остальные годы на уровне 500 тыс руб
# - в 2014 году 75% квартир стоило до 1,4 млн руб, а после сильно меньше, в районе 700-800 тыс. руб
#
# ##### Стоимость одного квадратного метра
# - самая высокая стоимость квадратного метра в Санкт-Петербурге - 114 054 рубля, самая низкая в Выборге - 58 251 рубль.
# - к наиболее дорогим городам относятся: Пушкин, Кудрово, Парголово
# - к ниаболее дешевым: Всеволожск, Гатчина, Колпино
#
# ##### Есть ли зависимость стоимости квартир от расстояния до центра Санкт-Петербурга
# - стоимость недвижимости зависит от удаленности от центра города
# - с увеличением удаленности от центра, цена уменьшается
# - самая высокая стоимость квартир в радиусе до 2-3 км
# - есть пик в районе 27 км, возможно это район новостроек с более дорогой ценой

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid FireBrick">
# <h5> ❌ <font color="FireBrick">Комментарий ревьюера (красный)</font></h5>
#
# В общем выводе хочется тезисно видеть все промежуточные выводы с цифрами. Это очень важно, поскольку топ-менеджеры, в большинстве своем, смотрят сразу сюда и только сюда...
#
# Тут важно обратиться к целям, которые были озвучены в самом начале и ответить на все вопросы. Важно оформить все тезисно и с цифрами. Еще важно описать все промежуточные выводы, которых не прописано в целях.
# Вкратце структура такая:
# - как были предобработаны данные(тут важно написать про изменения, если заполнялись пропуски или преобразовывались строки)
# - пройдись по целям и ответь на вопросы
# - добавь промежуточные выводы, которые считаешь нужным отметить
#
# Еще очень важно помнить, для кого ты делаешь проект, в зависимости от этого нужно сделать определенные акценты. В данном случае проект учебный, поэтому нужно ориентироваться по описанию.
#
# Для красивого оформления можешь воспользоваться [Кратким руководством по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/).
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info"; style="border-left: 7px solid SteelBlue">
# <h5>🎓 <font color="SteelBlue">Комментарий от студента (синий)</font></h5>
#
# Обновила основной вывод по твоим рекомендациям.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">v2 Комментарий ревьюера (зеленый)</font></h5>
#
# ✅ Спасибо, очень хороший и подробный общий вывод, которые содержит все промежуточные результаты 👍
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h5> ✔️ <font color="green">Комментарий ревьюера (зеленый)</font></h5>
#
# Хорошо, что ты ведешь чек-лист, он помогает ничего не забыть!
#
# </div>
