# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 3</b>
#
# Спасибо, что учла мои комментарии. Ты приложила много усилий, чтобы довести проект до конца, надеюсь, что эта работа помогла тебе лучше понять теорию. Я принимаю проект и желаю удачи в прохождении курса!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Привет еще раз. Спасибо, что доделала работу. Поправить осталось немного, вот комментарии, которые я оставила в этот раз:
#
# *[первый](#comm1)
#
# *[второй](#comm2)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Людмила, спасибо за проверку и ценные советы. Я удалила выводы картограмм на данном этапе, чтобы не перегружать проект и сохранить обновленный проект.
# </div>

# %% [markdown]
# Привет, Ирина.
#
# Меня зовут Людмила, и я буду проводить ревью твоего проекта.
#
# Предлагаю перейти на «ты», если не против)
#
# Но если это не удобно — дай знать, и мы перейдем на «вы». Моя главная задача — не находить сделанные тобою ошибки, а передать свой опыт и помочь тебе стать аналитиком данных.
#
# Мои комментарии будут в ячейках «Комментарий от ревьюера».
#
# ---
# <div class="alert alert-block alert-danger">
#
# Критическое замечание, которые следует исправить.
# </div>
#
# <div class="alert alert-block alert-warning">
#
# Замечание\совет на будущее.
# </div>
#
# <div class="alert alert-block alert-success">
#
# Когда всё сделано правильно.
# </div>
#
# ---
#
# Если ты вносишь изменения в проект по моим рекомендациям, указывай, пожалуйста, это в своих комментариях. Будет удобно, если обозначишь свои комментарии заметным цветом или поместишь
#
# <div class="alert alert-info">
#
# в такую ячейку
# </div>
#
# Давай при работе с проектом мы будем общаться с тобой в диалоге, поэтому не удаляй и не перемещай мои комментарии, это поможет мне сделать повторную  проверку проекта быстрее.
# ___

# %% [markdown]
# <div class="alert alert-info">
#
# Привет Людмила!
# </div>

# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# # Описание данных
#
# Файл moscow_places.csv:
#
# name — название заведения;
#
# address — адрес заведения;
#
# category — категория заведения, например «кафе», «пиццерия» или «кофейня»;
#
# hours — информация о днях и часах работы;
#
# lat — широта географической точки, в которой находится заведение;
#
# lng — долгота географической точки, в которой находится заведение;
#
# rating — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);
#
# price — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
#
# avg_bill — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
# «Средний счёт: 1000–1500 ₽»;
# «Цена чашки капучино: 130–220 ₽»;
# «Цена бокала пива: 400–600 ₽».
# и так далее;
#
# middle_avg_bill — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
#
# middle_coffee_cup — число с оценкой одной чашки капучино, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Цена одной чашки капучино»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.
#
# chain — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки):
# 0 — заведение не является сетевым
# 1 — заведение является сетевым
#
# district — административный район, в котором находится заведение, например Центральный административный округ;
#
# seats — количество посадочных мест.
#
#
# # Инструкция по выполнению проекта
#
# # Шаг 1. Загрузите данные и изучите общую информацию
#
# Загрузите данные о заведениях общественного питания Москвы.
#
# Путь к файлу: /datasets/moscow_places.csv. Скачать датасет.
#
# Изучите общую информацию о датасете. Сколько заведений представлено? Что можно сказать о каждом столбце? Значения какого типа они хранят?
#
# # Шаг 2. Выполните предобработку данных
#
# Изучите, есть ли дубликаты в данных. Поищите пропуски: встречаются ли они, в каких столбцах? Можно ли их обработать или оставить как есть?
#
# Выполните предобработку данных:
#
# Создайте столбец street с названиями улиц из столбца с адресом.
# Создайте столбец is_24_7 с обозначением, что заведение работает ежедневно и круглосуточно (24/7):
# логическое значение True — если заведение работает ежедневно и круглосуточно;
# логическое значение False — в противоположном случае.
#
# # Шаг 3. Анализ данных
#
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Ответьте на вопрос о распределении заведений по категориям.
#
# Исследуйте количество посадочных мест в местах по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Проанализируйте результаты и сделайте выводы.
#
# Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете. Каких заведений больше?
#
# Какие категории заведений чаще являются сетевыми? Исследуйте данные и ответьте на вопрос графиком.
#
# Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Под популярностью понимается количество заведений этой сети в регионе. Постройте подходящую для такой информации визуализацию. Знакомы ли вам эти сети? Есть ли какой-то признак, который их объединяет? К какой категории заведений они относятся?
#
# Какие административные районы Москвы присутствуют в датасете? Отобразите общее количество заведений и количество заведений каждой категории по районам. Попробуйте проиллюстрировать эту информацию одним графиком.
#
# Визуализируйте распределение средних рейтингов по категориям заведений. Сильно ли различаются усреднённые рейтинги в разных типах общепита?
#
# Постройте фоновую картограмму (хороплет) со средним рейтингом заведений каждого района. Границы районов Москвы, которые встречаются в датасете, хранятся в файле admin_level_geomap.geojson (скачать файл для локальной работы).
#
# Отобразите все заведения датасета на карте с помощью кластеров средствами библиотеки folium.
#
# Найдите топ-15 улиц по количеству заведений. Постройте график распределения количества заведений и их категорий по этим улицам. Попробуйте проиллюстрировать эту информацию одним графиком.
#
# Найдите улицы, на которых находится только один объект общепита. Что можно сказать об этих заведениях?
#
# Значения средних чеков заведений хранятся в столбце middle_avg_bill. Эти числа показывают примерную стоимость заказа в рублях, которая чаще всего выражена диапазоном. Посчитайте медиану этого столбца для каждого района. Используйте это значение в качестве ценового индикатора района. Постройте фоновую картограмму (хороплет) с полученными значениями для каждого района.
#
# Проанализируйте цены в центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях?
#
# Необязательное задание: проиллюстрируйте другие взаимосвязи, которые вы нашли в данных. Например, по желанию исследуйте часы работы заведений и их зависимость от расположения и категории заведения. Также можно исследовать особенности заведений с плохими рейтингами, средние чеки в таких местах и распределение по категориям заведений.
#
# Соберите наблюдения по вопросам выше в один общий вывод.
#
# # Шаг 4. Детализируем исследование: открытие кофейни
#
# Основателям фонда «Shut Up and Take My Money» не даёт покоя успех сериала «Друзья». Их мечта — открыть такую же крутую и доступную, как «Central Perk», кофейню в Москве. Будем считать, что заказчики не боятся конкуренции в этой сфере, ведь кофеен в больших городах уже достаточно. Попробуйте определить, осуществима ли мечта клиентов.
#
# Ответьте на следующие вопросы:
#
# Сколько всего кофеен в датасете? В каких районах их больше всего, каковы особенности их расположения?
#
# Есть ли круглосуточные кофейни?
#
# Какие у кофеен рейтинги? Как они распределяются по районам?
#
# На какую стоимость чашки капучино стоит ориентироваться при открытии и почему?
#
# По желанию вы можете расширить список вопросов для исследования, добавив собственные.
#
# Постройте визуализации. Попробуйте дать рекомендацию для открытия нового заведения. Это творческое задание: здесь нет правильного или неправильного ответа, но ваше решение должно быть чем-то обосновано. Объяснить свою рекомендацию можно текстом с описанием или маркерами на географической карте.
#
# # Шаг 5. Подготовка презентации
#
# Подготовьте презентацию исследования для инвесторов. Отвечая на вопросы о московском общепите, вы уже построили много диаграмм, и помещать каждую из них в презентацию не нужно. Выберите важные тезисы и наблюдения, которые могут заинтересовать заказчиков.
# Для создания презентации используйте любой удобный инструмент, но отправить презентацию нужно обязательно в формате PDF.
#
# Приложите ссылку на презентацию в markdown-ячейке в формате:
#
# Презентация: <ссылка на облачное хранилище с презентацией>
#
# Следуйте принципам оформления из темы «Подготовка презентации».

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера:</b> Хорошо, что во вступительной части ты указываешь всю важную информацию о проекте.
# </div>

# %% [markdown]
# # Загрузка данных

# %%
# загружаем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import plotly.io as pio
import math as mth
import re
import folium
import json
from folium import Map, Marker # импортируем карту и маркер
from folium.plugins import MarkerCluster # импортируем кластер
from folium import Choropleth # импортируем карту и хороплет
from datetime import datetime, timedelta
from plotly import graph_objects as go
import plotly.express as px
sns.set(rc={'figure.figsize':(20, 12)})
plt.figure(figsize=(20, 12))

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Ты 2 раза загружаешь `Map`. Один можно убрать.
#
# </div>

# %%
# загружаем настройки отображения
pd.set_option('display.max_columns', 50)
pd.options.mode.chained_assignment = None  
pd.options.display.max_colwidth = 400
pd.options.display.float_format = '{:,.2f}'.format

# %%
# загружаем файл
data = pd.read_csv('/datasets/moscow_places.csv', delimiter=',')

# %%
display(data.head())
display(data.info())
# Out:
#                    name  category                              address  \
# 0                WoWфли      кафе           Москва, улица Дыбенко, 7/1
# 1        Четыре комнаты  ресторан   Москва, улица Дыбенко, 36, корп. 1
# 2                 Хазри      кафе       Москва, Клязьминская улица, 15
# 3  Dormouse Coffee Shop   кофейня  Москва, улица Маршала Федоренко, 12
# 4             Иль Марко  пиццерия      Москва, Правобережная улица, 1Б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                   hours   lat   lng  rating  \
# 0                                ежедневно, 10:00–22:00 55.88 37.48    5.00
# 1                                ежедневно, 10:00–22:00 55.88 37.48    4.50
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00–02:00 55.89 37.53    4.60
# ...

# %% [markdown]
# Выводы:
#
# - всего в датасете 8406 заведений
#
# - наименования столбцов корректны
#
# - типы данных во всех столбцах корректны, кроме seats (количество мест в заведении не может быть дробным)
#
# - типы данных: float64, int64, object

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера:</b> Всё верно, можно переходить к предобработке.
# </div>

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Проверим дубликаты и пропуски в данных.

# %%
print('Количество пропущенных значений:', data.isnull().sum().sum())
print('Количество дубликатов: ', data.duplicated().sum())
print('Итого процент дубликатов составляет: ','{:.1%}'.format((data.duplicated().sum() / len(data))))
# Out:
# Количество пропущенных значений: 26956
# Количество дубликатов:  0
# Итого процент дубликатов составляет:  0.0%

# %%
# посчитаем пропуски в столбцах в % от общего количества строк
data.isna().sum() / len(data) * 100
# Out:
# name                 0.00
# category             0.00
# address              0.00
# district             0.00
# hours                6.38
# lat                  0.00
# lng                  0.00
# rating               0.00
# price               60.56
# avg_bill            54.60
# middle_avg_bill     62.54
# middle_coffee_cup   93.64
# chain                0.00
# seats               42.96
# dtype: float64

# %% [markdown]
# Пропуски в данных присутствуют в столбцах hours, price, avg_bill, middle_avg_bill, middle_coffee_cup, seats. Так как количество пропусков значительное, не будем удалять строки, оставим данные как есть, заменим пропуски на -1.

# %%
# заменим пропуски столбцов 'seats', 'middle_coffee_cup', 'middle_avg_bill' на -1
for column in ['seats', 'middle_coffee_cup', 'middle_avg_bill']:
    data[column] = data[column].fillna(-1)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b>
#
# В данных столбцах лучше заменить пропуски на такое значение, которое можно будет отсеять при расчетах (например -1), либо оставить пропуски без заполнения.
#
# Например в расчете количества мест по категориям не учитывается заполнение пропусков, и это сильно влияет на результаты.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Заменила на -1
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b> Комментарий от ревьюера 2</b>
#
# Да, этот вариант лучше подойдет в качестве "заглушки".
#
# </div>

# %% [markdown]
# Заменим тип данных на целочисленный в столбцах seats, middle_coffee_cup, middle_avg_bill

# %%
data[['seats', 'middle_coffee_cup', 'middle_avg_bill']] = data[['seats', 'middle_coffee_cup', 'middle_avg_bill']].astype (int)

# %%
# посмотрим на результат
display(data.head(5))
# Out:
#                    name  category                              address  \
# 0                WoWфли      кафе           Москва, улица Дыбенко, 7/1
# 1        Четыре комнаты  ресторан   Москва, улица Дыбенко, 36, корп. 1
# 2                 Хазри      кафе       Москва, Клязьминская улица, 15
# 3  Dormouse Coffee Shop   кофейня  Москва, улица Маршала Федоренко, 12
# 4             Иль Марко  пиццерия      Москва, Правобережная улица, 1Б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                   hours   lat   lng  rating  \
# 0                                ежедневно, 10:00–22:00 55.88 37.48    5.00
# 1                                ежедневно, 10:00–22:00 55.88 37.48    4.50
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00–02:00 55.89 37.53    4.60
# ...

# %%
# приведем в нижний регистр столбцы name, address, avg_bill
for col in ['name', 'address', 'avg_bill']:
    data[col] = data[col].str.lower()

# %%
# посмотрим на явные дубликаты в столбцах 'name', 'address'
data.duplicated(subset=['name', 'address']).sum()
# Out:
# 4

# %% [markdown]
# Найдено 4 дубликата строк.

# %%
# посмотрим на дубликаты
data.loc[data.duplicated(subset=['name', 'address'], keep=False)]
# Out:
#                            name  category  \
# 189                        кафе      кафе
# 215                        кафе      кафе
# 1430                  more poke  ресторан
# 1511                  more poke  ресторан
# 2211  раковарня клешни и хвосты  ресторан
# 2420  раковарня клешни и хвосты   бар,паб
# 3091            хлеб да выпечка  булочная
# 3109            хлеб да выпечка      кафе
#
#                                       address  \
# 189              москва, парк ангарские пруды
# 215              москва, парк ангарские пруды
# 1430  москва, волоколамское шоссе, 11, стр. 2
# 1511  москва, волоколамское шоссе, 11, стр. 2
# 2211               москва, проспект мира, 118
# 2420               москва, проспект мира, 118
# 3091              москва, ярцевская улица, 19
# 3109              москва, ярцевская улица, 19
#
#                                      district  \
# 189           Северный административный округ
# 215           Северный административный округ
# ...

# %%
# удаляем дубликаты
data.drop_duplicates(subset=['name', 'address'], keep='first', inplace=True)

# %% [markdown]
# Проверим на дубликаты еще раз, после удаления строк.

# %%
data.duplicated(subset=['name', 'address']).sum()
# Out:
# 0

# %% [markdown]
# Дубликатов не найдено.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Комментарий ревьюера:</b> Чтобы найти таким способом неявные дубликаты, надо сначала привести все названия к одному регистру.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Исправила
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера 2:</b> Всё верно, дубликатов было немного.
# </div>

# %% [markdown]
# Проверим районы на дубликаты.

# %%
data['district'].unique()
# Out:
# array(['Северный административный округ',
#        'Северо-Восточный административный округ',
#        'Северо-Западный административный округ',
#        'Западный административный округ',
#        'Центральный административный округ',
#        'Восточный административный округ',
#        'Юго-Восточный административный округ',
#        'Южный административный округ',
#        'Юго-Западный административный округ'], dtype=object)

# %%
# проверим категории заведений на дубликаты
data['category'].unique()
# Out:
# array(['кафе', 'ресторан', 'кофейня', 'пиццерия', 'бар,паб',
#        'быстрое питание', 'булочная', 'столовая'], dtype=object)

# %%
# проверим категирии цен на дубликаты
data['price'].unique()
# Out:
# array([nan, 'выше среднего', 'средние', 'высокие', 'низкие'], dtype=object)

# %% [markdown]
# Создание столбца street с названиями улиц из столбца с адресом.

# %%
# напишем функцию для выделения улицы из адреса
def street(row):
    address = row['address'].split(', ')
    street = address[1]
    return street
data['street'] = data.apply(street, axis=1)
data.head(5)
# Out:
#                    name  category                              address  \
# 0                wowфли      кафе           москва, улица дыбенко, 7/1
# 1        четыре комнаты  ресторан   москва, улица дыбенко, 36, корп. 1
# 2                 хазри      кафе       москва, клязьминская улица, 15
# 3  dormouse coffee shop   кофейня  москва, улица маршала федоренко, 12
# 4             иль марко  пиццерия      москва, правобережная улица, 1б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                   hours   lat   lng  rating  \
# 0                                ежедневно, 10:00–22:00 55.88 37.48    5.00
# 1                                ежедневно, 10:00–22:00 55.88 37.48    4.50
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00–02:00 55.89 37.53    4.60
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Хорошо, что ты учитываешь пробел, когда выделяешь улицу.
#
# </div>

# %% [markdown]
# Создадим столбец is_24_7 с обозначением, что заведение работает ежедневно и круглосуточно (24/7):
#
# логическое значение True — если заведение работает ежедневно и круглосуточно;
#
# логическое значение False — в противоположном случае.

# %%
# создадим новый столбец 'is_24_7'
data['is_24_7'] = data[data['hours'].apply(lambda x: 'ежедневно, круглосуточно' in str(x))]['hours'] == 'ежедневно, круглосуточно'
data['is_24_7'] = data['is_24_7'].fillna(False)
data.head(5)
# Out:
#                    name  category                              address  \
# 0                wowфли      кафе           москва, улица дыбенко, 7/1
# 1        четыре комнаты  ресторан   москва, улица дыбенко, 36, корп. 1
# 2                 хазри      кафе       москва, клязьминская улица, 15
# 3  dormouse coffee shop   кофейня  москва, улица маршала федоренко, 12
# 4             иль марко  пиццерия      москва, правобережная улица, 1б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                   hours   lat   lng  rating  \
# 0                                ежедневно, 10:00–22:00 55.88 37.48    5.00
# 1                                ежедневно, 10:00–22:00 55.88 37.48    4.50
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00–02:00 55.89 37.53    4.60
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Верно, этот режим работы подходит.
# </div>

# %% [markdown]
# Вывод:
#
# - выявлены пропуски в данных, сделана замена пропусков на значение -1
# - столбцы проверены на явные дубликаты, явные дубликаты не обнаружены в столбцах district, category, price
# - выявлены и удалены дубликаты 4 строк
# - заменили тип данных на целочисленный в столбцах seats, middle_coffee_cup, middle_avg_bill
# - добавлены столбцы street и is_24_7

# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## Распределение заведений по категориям

# %%
# сгруппируем данные в таблицу
rest = data.groupby('category')['name'].count().sort_values(ascending=False).reset_index()
rest['%'] = rest['name'] / len(data) * 100
display(rest)
# Out:
#           category  name     %
# 0             кафе  2376 28.28
# 1         ресторан  2042 24.30
# 2          кофейня  1413 16.82
# 3          бар,паб   764  9.09
# 4         пиццерия   633  7.53
# 5  быстрое питание   603  7.18
# 6         столовая   315  3.75
# 7         булочная   256  3.05

# %%
# построим гистограмму
plt.figure(figsize=(20, 12))
with plt.style.context('seaborn-whitegrid'):
    plt.bar(rest['category'], rest['name'], color='green', width = 0.5) 
    plt.xlabel("Категория")
    plt.ylabel("Количество объектов общественного питания")
    plt.title("Количество объектов общественного питания по категориям")
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера:</b> Хорошо, что все столбцы на графике одного цвета: так лишняя информация не будет отвлекать внимание.
# </div>

# %% [markdown]
# Вывод:
#
# - самое большое количество заведений в категории - кафе, затем идут - ресторан и кофейня
#
# - кафе и рестораны составляют большинство заведений общественного питания - 52%

# %% [markdown]
# ## Количество посадочных мест в местах по категориям

# %%
# сгруппируем данные
seats_sum = data.query('seats != -1').groupby('category')['seats'].sum().sort_values(ascending=False).reset_index()
seats_sum.columns = ['category', 'seats']
seats_sum
# Out:
#           category   seats
# 0         ресторан  154681
# 1             кафе  118494
# 2          кофейня   83511
# 3          бар,паб   58131
# 4         пиццерия   40350
# 5  быстрое питание   34513
# 6         столовая   16359
# 7         булочная   13229

# %%
# построим гистограмму
with plt.style.context('seaborn-whitegrid'):
    plt.bar(seats_sum['category'], seats_sum['seats'], color='green', width = 0.5) 
    plt.xlabel("Категория")
    plt.ylabel("Количество посадочных мест")
    plt.title("Объекты общественного питания по количеству посадочных мест")
    plt.show()

# %% [markdown]
# Самое большое количество посадочных мест, суммарно, имеет категория "ресторан" - более 150 тыс, затем идут категории "кафе" и "кофейня".

# %%
# посмотрим на описательные характеристики столбца "seats"
data.query('seats != -1')['seats'].describe()
# Out:
# count   4,792.00
# mean      108.36
# std       122.84
# min         0.00
# 25%        40.00
# 50%        75.00
# 75%       140.00
# max     1,288.00
# Name: seats, dtype: float64

# %% [markdown]
# Среднее число мест в заведении - 108. Не менее 75% заведений имеют до 140 посадочных мест. Максимальное количество мест в заведении - 1288 (возможно здесь ошибка в данных).

# %%
# построим гистограмму на 12 корзин и изучим распределение
with plt.style.context('seaborn-whitegrid'):
    data.query('seats != -1')['seats'].hist(bins=10, figsize=(5,5), color='green')
    None
plt.xlabel("Количество посадочных мест")
plt.ylabel("Количество заведений")
plt.title("Объекты общественного питания по количеству посадочных мест")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b>
#
# Дальше у некоторых графиков не хватает названий и/или подписей осей либо вместо подписей осей отображаются названия столбцов (например как на следующем графике). Пожалуйста, дополни оформление графиков, чтобы все визуализации в проекте было легко понять.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Исправила
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Комментарий ревьюера 2:</b>
#
# Здорово, так графики выглядят очень аккуратно.
# </div>

# %% [markdown]
# Гистограмма показывает, что большинство заведений имеют количество мест до 400.

# %%
# посмотрим на распределение по количеству посадочных мест в объектах общественного питания
order = data.query('seats != -1').groupby(by=["category"])["seats"].median().fillna(0).sort_values()[::-1].index
with plt.style.context('seaborn-whitegrid'):
    sns.boxplot(x='seats', y='category', data=data.query('seats != -1'), order=order, palette='Greens')
plt.xlabel("Количество посадочных мест")
plt.ylabel("Категории заведений")
plt.title("Объекты общественного питания по количеству посадочных мест")
plt.show()
None

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> Диаграмма размаха достаточно сложный для восприятия график, поэтому хорошо бы постараться её упростить. По [ссылке](https://stackoverflow.com/questions/39214484/how-to-rank-plot-in-seaborn-boxplot) есть пример, как добавить на такой график сортировку (только в нашем случае надо использовать медиану).
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Обновила график
# </div>

# %% [markdown]
# <a id="comm1"></a>
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера 2:</b>
#
# В order надо добавить еще выделение строк, не заполненных значением -1. Тогда сортировка будет более точной.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Добавила фильтр -1 в order
# </div>

# %% [markdown]
# Вывод:
#
# - суммарно, самое большое количество мест в категории "ресторан" - более 150000; затем идут "кафе" и "кафейня"
#
# - среднее число мест в заведении - 108, не менее 75% заведений имеют до 140 посадочных мест
#
# - большинство объектов общественного питания имеют до 400 посадочных мест

# %% [markdown]
# ## Соотношение сетевых и несетевых заведений

# %%
print("Всего сетевых", data['chain'].sum(), 'из', len(data), 'объектов общественного питания')
print("Сетевых в %: ", '{:.0%}'.format(data['chain'].sum() / len(data)))
# Out:
# Всего сетевых 3203 из 8402 объектов общественного питания
# Сетевых в %:  38%

# %%
chain_data = data.groupby('chain', as_index=False)['chain'].count()
chain_data = chain_data.reset_index()
chain_data.columns = ['тип', 'количество']
chain_data['тип'] = chain_data['тип'].apply(lambda x: 'несетевые' if x == 0 else 'сетевые')
chain_data
# Out:
#          тип  количество
# 0  несетевые        5199
# 1    сетевые        3203

# %%
with plt.style.context('seaborn-whitegrid'):
    sns.set_palette('Greens_r') 
    plt.figure(figsize=(7, 7))
    y = chain_data['количество']
    mylabels = chain_data['тип']
    plt.pie(y, labels = mylabels,  autopct='%1.1f%%',  textprops={'fontsize': 14})
    plt.title("Соотношение сетевых/несетевых заведений", fontsize=16)
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> Для этого вопроса нас тоже просят сделать визуализацию. Пожалуйста, добавь ее сюда.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Добавила визуализацию
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b> Хорошо, что ты заменила бинарный признак в столбце на понятные подписи.
# </div>

# %%
# сгруппируем данные в сводную таблицу
chain = data.pivot_table(index = 'category', values='name', columns = 'chain', aggfunc='count').sort_values(by=0, ascending=False).reset_index()
chain.columns = ('category', 'не сетевые', 'сетевые')
chain['total'] = chain['не сетевые'] + chain['сетевые']
chain['%'] = chain['сетевые'] / chain['total'] * 100
chain.sort_values(by='%', ascending=False)
# Out:
#           category  не сетевые  сетевые  total     %
# 7         булочная          99      157    256 61.33
# 5         пиццерия         303      330    633 52.13
# 2          кофейня         693      720   1413 50.96
# 4  быстрое питание         371      232    603 38.47
# 1         ресторан        1313      729   2042 35.70
# 0             кафе        1597      779   2376 32.79
# 6         столовая         227       88    315 27.94
# 3          бар,паб         596      168    764 21.99

# %%
# построим гистограмму с накоплением
with plt.style.context('seaborn-whitegrid'):
    sns.set_palette('Greens_r') 
    chain['%'].sort_values().plot(kind='barh', y=chain['category'].index, x=chain['%'].values.sort(), title='% сетевых заведений общественного питания')
    plt.yticks(np.arange(8),('бар,паб', 'столовая', 'кафе', 'ресторан', 'быстрое питание', 'кофейня', 'пиццерия', 'булочная'))
    plt.legend(('% cетевых'))
    None

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> Чтобы понять, какие категории заведений чаще являются сетевыми, будет лучше показать на графике столбец %.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Изменила график
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Да, это тот расчет, который нам нужен.
# </div>

# %% [markdown]
# Вывод:
#
# - к сетям относятся только 38% объектов
#
# - чаще всего сетевые - булочные (61%), пиццерии (52%) и кофейни (51%)

# %% [markdown]
# ##  Топ-15 популярных сетей в Москве

# %%
# сгруппируем данные по названию 
chain_new = data[data['chain'] == 1]
top = chain_new.groupby('name').agg({'rating' : 'median', 'category' : pd.Series.mode, 'name' : 'count'})
top = top.rename(columns={'name':'count'})
top_15 = top.sort_values(by='count', ascending=False).reset_index().head(15)
print('Всего заведений в ТОП-15:', top_15['count'].sum())
print('Доля ТОП-15 в всех сетевых:', '{:.0%}'.format(top_15['count'].sum() / data['chain'].sum()))
top_15
# Out:
# Всего заведений в ТОП-15: 816
# Доля ТОП-15 в всех сетевых: 25%
#                                    name  rating  category  count
# 0                           шоколадница    4.20   кофейня    120
# 1                        домино'с пицца    4.20  пиццерия     76
# 2                            додо пицца    4.30  пиццерия     74
# 3                      one price coffee    4.20   кофейня     71
# 4                          яндекс лавка    4.00  ресторан     69
# 5                                 cofix    4.10   кофейня     65
# 6                                 prime    4.20  ресторан     50
# 7                            хинкальная    4.40      кафе     44
# 8                              кофепорт    4.20   кофейня     42
# 9   кулинарная лавка братьев караваевых    4.40      кафе     39
# 10                              теремок    4.10  ресторан     38
# 11                              чайхана    4.10      кафе     37
# ...

# %% [markdown]
# Построим график ТОП-15 кофеен

# %%
with plt.style.context('seaborn-whitegrid'):
    sns.set_palette('Greens_r') 
    top_15.plot(kind = 'barh', y = 'count')
    plt.title('ТОП-15 сетей по количеству заведений')
    plt.xlabel('Количество')
    plt.ylabel('Сеть')
    plt.yticks(np.arange(15), (top_15['name']))
    plt.gca().invert_yaxis()
    plt.legend()
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Ты правильно выделила популярные сети.
# </div>

# %%
# сгруппируем данные по категориям
spisok_top_15 = top_15['name'].unique() #создаем список топ-15 сетей
data_top_15 = data[data['name'].isin(spisok_top_15)]
top_15_new = data_top_15.groupby('category', as_index=False).agg({'name' : 'count'}).sort_values(by='name', ascending=False)
top_15_new = top_15_new.rename(columns={'category':'category', 'name':'count'})
top_15_new['%'] = (top_15_new['count'] / top_15_new['count'].sum()) * 100
top_15_new
# Out:
#           category  count     %
# 4          кофейня    337 41.20
# 6         ресторан    186 22.74
# 5         пиццерия    152 18.58
# 3             кафе    100 12.22
# 1         булочная     25  3.06
# 2  быстрое питание     12  1.47
# 0          бар,паб      4  0.49
# 7         столовая      2  0.24

# %% [markdown]
# Больше всего заведений кофеен - 337 штук.

# %%
# строим гистограмму
bar,ax = plt.subplots(figsize=(15, 9))
ax = sns.barplot(x='category', y='count', data=top_15_new, ci=None, palette= "Greens_r")
ax.set_title("Распределение сетевых заведений по категориям", fontsize=15)
ax.set_xlabel ("Категория заведения")
ax.set_ylabel ("Количество заведений")

for i in ax.patches:
        _x = i.get_x() + i.get_width() / 2
        _y = i.get_y() + i.get_height() + (i.get_height()*0.01)
        value = '{:.2f}'.format(i.get_height())
        ax.text(_x, _y, value, ha="center")
        
plt.show()

# %% [markdown]
# Вывод:
#
# - в ТОП-15 входят известные сети общественного питания
#
# - самой популярной сетью является - Шоколадница (120 объектов), затем идут пиццерии -  Доминос Пицца и Додо Пицца
#
# - всего в ТОП-15 - 816 заведений, это составляет 25% от всех сетевых
#
# - 41% заведений в ТОП-15 составляют кофейни

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера:</b> Стоит построить дополнительную визуализацию для ответа на вопрос, к какой категории относятся топ-15 сетей. При этом нужно учесть, что для некоторых заведений могут быть указаны разные категории. Поэтому лучше всего сделать так:
#
# * отфильтровать общую таблицу по списку названий топ-15 сетей:
#
# https://datascientyst.com/select-rows-list-values-pandas-dataframe/
#
# * построить график с количеством заведений по категориям на основе этой таблицы:
#
# ![2023-08-04%2004%2027%2035.png](attachment:2023-08-04%2004%2027%2035.png)
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Добавила выше график
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Здорово, получился верный график.
# </div>

# %% [markdown]
# ## Количество заведений и количество заведений каждой категории по районам

# %%
data['district'].unique()
# Out:
# array(['Северный административный округ',
#        'Северо-Восточный административный округ',
#        'Северо-Западный административный округ',
#        'Западный административный округ',
#        'Центральный административный округ',
#        'Восточный административный округ',
#        'Юго-Восточный административный округ',
#        'Южный административный округ',
#        'Юго-Западный административный округ'], dtype=object)

# %%
# создадим новый столбец с сокращенным названием района
district = {
    'Северный административный округ': 'САО',
    'Северо-Западный административный округ': 'СЗАО',
    'Западный административный округ': 'ЗАО',
    'Восточный административный округ': 'ВАО',
    'Юго-Западный административный округ': 'ЮЗАО',
    'Южный административный округ': 'ЮАО',
    'Юго-Восточный административный округ': 'ЮВАО',
    'Центральный административный округ': 'ЦАО',
    'Северо-Восточный административный округ': 'СВАО',
    'Зеленоградский административный округ': 'ЗАО'
}

data['distr'] = data['district'].replace(district)

# %%
# сгруппируем данные по районам
distr = data.groupby('distr', as_index=False).agg({'name': 'count'}).sort_values(by='name', ascending=False)
distr = distr.rename(columns={'name':'Количество'})
distr['%'] = (distr['Количество'] / distr['Количество'].sum()) * 100
distr
# Out:
#   distr  Количество     %
# 5   ЦАО        2242 26.68
# 2   САО         898 10.69
# 6   ЮАО         892 10.62
# 3  СВАО         890 10.59
# 1   ЗАО         850 10.12
# 0   ВАО         798  9.50
# 7  ЮВАО         714  8.50
# 8  ЮЗАО         709  8.44
# 4  СЗАО         409  4.87

# %% [markdown]
# Больше всего заведений находится в ЦАО - 27%. Затем следуют районы - САО, ЮАО, СВАО, ЗАО (по 11%).

# %%
# сгруппируем данные по районам и категориям
list_distr = distr['distr'].unique()
distr_cat = data.groupby(['category', 'distr'])['distr'].count().unstack('category').reindex(list_distr)
distr_cat.columns = ['бар,паб', 'булочная', 'быстрое питание', 'кафе', 'кофейня', 'пиццерия', 'ресторан', 'столовая']
#distr_cat.reindex('list_distr')
#distr_cat['itogo'] = distr_cat.loc[:, 'бар,паб':'столовая'].apply(lambda x: x.sum(), axis = 1)
distr_cat
# Out:
#        бар,паб  булочная  быстрое питание  кафе  кофейня  пиццерия  ресторан  \
# distr
# ЦАО        364        50               87   464      428       113       670
# САО         68        39               58   234      193        77       188
# ЮАО         68        25               85   264      131        73       202
# СВАО        62        28               82   269      159        68       182
# ЗАО         50        37               62   238      150        71       218
# ВАО         53        25               71   272      105        72       160
# ЮВАО        38        13               67   282       89        55       145
# ЮЗАО        38        27               61   238       96        64       168
# СЗАО        23        12               30   115       62        40       109
#
#        столовая
# distr
# ЦАО          66
# САО          41
# ЮАО          44
# СВАО         40
# ЗАО          24
# ВАО          40
# ЮВАО         25
# ЮЗАО         17
# СЗАО         18

# %%
# переведем в %
distr_cat_new = distr_cat.apply(lambda x: x / x.sum() * 100, axis = 1)
#distr_cat_new.style.format('{:.0f}%')
col = distr_cat_new.columns
distr_cat_new.style.highlight_max(color='yellowgreen', subset=col, axis = 1).highlight_min(color='red', subset=col, axis = 1)

# %%
distr_cat.plot(kind='bar', stacked=True , color=['yellowgreen', 'green', 'olive', 'khaki', 'greenyellow', 'lime', 'darkgreen', 'darkkhaki'])
plt.title('Стуктура по категориям заведений в разрезе районов', fontsize= 16)
plt.xlabel('Улица')
plt.ylabel('Количество заведений')
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b>
#
# На таком графике будет тяжело сравнить общее количество заведений по районам. Для этого вопроса лучше подойдет диаграмма с накоплением, как для топ-15 улиц или как во втором примере по ссылке ниже.
#
# https://plotly.com/python/bar-charts/

# %% [markdown]
# <div class="alert alert-info">
#
# Изменила график
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Молодец, что добавила для графика сортировку.
# </div>

# %% [markdown]
# Выводы:
#
# - на фоне всех округов выделяется ЦАО, в нем расположено самое большое количество заведений - 2242 или 27% от всего количества
#
# - больше всего в ЦАО ресторанов - 670 или 30%, заатем идут кафе, кофейни и бары
#
# - меньше всего в ЦАО булочных
#
# - лучше всего представлены во всех округах кафе от 39% до 20%, хуже всего - булочные от 4% до 2%

# %% [markdown]
# ## Распределение средних рейтингов по категориям заведений

# %%
# сгруппируем данные по рейтингу
rating_avg = data.groupby('category').agg({'rating' : 'mean', 'name' : 'count'}).sort_values(by='rating', ascending=False)
rating_avg.columns = ['avg_rating', 'count']
rating_avg
# Out:
#                  avg_rating  count
# category
# бар,паб                4.39    764
# пиццерия               4.30    633
# ресторан               4.29   2042
# кофейня                4.28   1413
# булочная               4.27    256
# столовая               4.21    315
# кафе                   4.12   2376
# быстрое питание        4.05    603

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Так как в столбце с рейтингом нет выбросов, здесь хорошо подойдет для расчета среднее.
# </div>

# %%
# строим гистограмму
bar,ax = plt.subplots(figsize=(15, 9))
ax = sns.barplot(x='avg_rating', y=rating_avg.index, data=rating_avg, ci=None, palette= "Greens_r", orient='h' )
ax.set_title("Средний рейтинг объектов общественного питания в Москве", fontsize=15)
ax.set_xlabel ("Процентное соотношение")
ax.set_ylabel ("Тип заведения")
for rect in ax.patches: # пишем значения
    ax.text (rect.get_width(), rect.get_y() + rect.get_height() / 2, "%.2f"% rect.get_width(), weight='bold')
plt.xlim(4, 4.5) #ограничиваем ось х
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Здорово, что ты ограничиваешь масштаб: без этого столбцы становятся практически одинаковыми.
# </div>

# %% [markdown]
# Выводы:
#
# - средние рейтинги категорий заведений отличаются минимально друг от друга от 4.05 до 4.39
#
# - самый высокий рейтинг у заведений категорий 'бар,паб', самый низкий у категории 'быстрое питание'

# %% [markdown]
# ## Фоновая картограмма (хороплет) со средним рейтингом заведений каждого района

# %%
rating_df = data.groupby('district', as_index=False)['rating'].agg('mean')
rating_df
# Out:
#                                   district  rating
# 0         Восточный административный округ    4.17
# 1          Западный административный округ    4.18
# 2          Северный административный округ    4.24
# 3  Северо-Восточный административный округ    4.15
# 4   Северо-Западный административный округ    4.21
# 5       Центральный административный округ    4.38
# 6     Юго-Восточный административный округ    4.10
# 7      Юго-Западный административный округ    4.17
# 8             Южный административный округ    4.18

# %%
# загружаем JSON-файл с границами округов Москвы
state_geo = '/datasets/admin_level_geomap.geojson'

#moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=rating_df,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Средний рейтинг заведений по районам',
).add_to(m)

# выводим карту
#m

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Карта отлично показывает разницу по районам.
#
# </div>

# %% [markdown]
# Выводы:
#
# - самый высокий средний рейтинг в Центральном административном округе
#
# - затем идут САО и СЗАО

# %% [markdown]
# ## Карта с кластерами заведений средствами библиотеки folium

# %%
#moscow_lat - широта центра Москвы, moscow_lng - долгота центра Москвы
moscow_lat, moscow_lng = 55.751244, 37.618423

# создаём карту Москвы
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')


# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster

def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)
# пишем функцию, которая принимает строку датафрейма,

# применяем функцию для создания маркера к первым 5 записям датафрейма
data.apply(create_clusters, axis=1)
    
# выводим карту
#m
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 8401    None
# 8402    None
# 8403    None
# 8404    None
# 8405    None
# Length: 8402, dtype: object

# %% [markdown]
# Вывод:
#
# - по карте видно, что заведения общественного питания сконцентрированы в центре Москвы

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Сюда бы хорошо добавить краткий вывод, иначе пункт выглядит незавершенным.

# %% [markdown]
# <div class="alert alert-info">
#
# Добавила вывод.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Отлично: проект выглядит очень аккуратно, когда выводы есть в каждом пункте.
# </div>

# %% [markdown]
# ## Топ-15 улиц по количеству заведений, график распределения количества заведений и их категорий по этим улицам

# %%
street_top_15 = data.groupby(['street'], as_index=False)['name'].count().sort_values(by='name', ascending=False).head(15)
street_top_15 = street_top_15.sort_values(by='name', ascending=False)
street_top_15.columns = ['street', 'count_street']
street_top_15
# Out:
#                       street  count_street
# 837            проспект мира           183
# 841        профсоюзная улица           122
# 834     проспект вернадского           108
# 533       ленинский проспект           107
# 531   ленинградский проспект            95
# 379        дмитровское шоссе            88
# 461          каширское шоссе            77
# 304         варшавское шоссе            76
# 532      ленинградское шоссе            70
# 610                     мкад            65
# 555         люблинская улица            60
# 1076          улица вавилова            55
# 523     кутузовский проспект            54
# 1231    улица миклухо-маклая            49
# 849          пятницкая улица            48

# %%
list_street = street_top_15['street'].unique()
street_cat = data.groupby(['street', 'category'])['street'].count().unstack('category').reindex(list_street)
street_cat.columns = ['бар,паб', 'булочная', 'быстрое питание', 'кафе', 'кофейня', 'пиццерия', 'ресторан', 'столовая']
dt = street_cat.merge(street_top_15['street'], how='inner', on='street').fillna(0)
float_col = dt.select_dtypes(include=['float64'])
for col in float_col.columns.values:
    dt[col] = dt[col].astype('int64')
dt = dt.set_index(['street'])
dt.sort_values(by='ресторан', ascending=False)
# Out:
#                         бар,паб  булочная  быстрое питание  кафе  кофейня  \
# street
# проспект мира                11         4               21    53       36
# проспект вернадского          7         1               12    25       16
# ленинский проспект           10         3                2    26       23
# профсоюзная улица             6         4               15    35       18
# ленинградское шоссе           5         2                5    13       13
# ленинградский проспект       15         4                2    12       25
# дмитровское шоссе             6         2               10    23       11
# варшавское шоссе              6         0                7    18       14
# каширское шоссе               2         0               10    20       16
# пятницкая улица               9         3                2     7        6
# кутузовский проспект          2         1                2    14       13
# улица миклухо-маклая          3         0                4    21        4
# ...

# %%
dt.plot(kind='bar', stacked=True , color=['yellowgreen', 'green', 'olive', 'khaki', 'greenyellow', 'lime', 'darkgreen', 'darkkhaki'])
plt.title('Стуктура по категориям заведений в разрезе улиц', fontsize= 16)
plt.xlabel('Улица')
plt.ylabel('Количество заведений')
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> Этот график хорошо подходит для ответа на вопрос, но на него тоже надо добавить сортировку. Например можно отсортировать таблицу с помощью [reindex](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reindex.html).
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Добавила сортировку на график
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Интересный способ сортировки.
# </div>

# %% [markdown]
# Выводы:
#
# - самое большое количество заведений общественного питания находится на улице проспект Мира - 183
#
# - в тройку лидеров также вошли Профсоюзная улица и проспект Вернадского

# %% [markdown]
# ## Улицы, на которых находится только один объект общепита

# %%
# сгруппируем данные
one_street = data.pivot_table(index=('street', 'distr'), values='name', aggfunc='count').reset_index()
one_street.columns = ['street', 'distr', 'count']
one_street = one_street.query('count==1')
one_street
# Out:
#                                    street distr  count
# 0                1-й автозаводский проезд   ЮАО      1
# 1                 1-й балтийский переулок   САО      1
# 2                   1-й варшавский проезд   ЮАО      1
# 3                 1-й вешняковский проезд  ЮВАО      1
# 5               1-й голутвинский переулок   ЦАО      1
# ...                                   ...   ...    ...
# 1471               электрический переулок   ЦАО      1
# 1478  юго-западный административный округ  ЮЗАО      1
# 1483                  якиманский переулок   ЦАО      1
# 1484           яковоапостольский переулок   ЦАО      1
# 1492                                  № 7   ЮАО      1
#
# [475 rows x 3 columns]

# %% [markdown]
# В датасете 458 улиц с 1 заведением общественного питания.

# %%
one_st = one_street.groupby(['distr'], as_index=False)['count'].count().sort_values(by='count', ascending=False)
one_st['%'] = one_st['count'] / one_st['count'].sum() * 100
one_st
# Out:
#   distr  count     %
# 5   ЦАО    148 31.16
# 3  СВАО     56 11.79
# 0   ВАО     52 10.95
# 2   САО     52 10.95
# 6   ЮАО     50 10.53
# 7  ЮВАО     42  8.84
# 1   ЗАО     36  7.58
# 4  СЗАО     21  4.42
# 8  ЮЗАО     18  3.79

# %%
# строим гистограмму
bar,ax = plt.subplots(figsize=(15, 9))
ax = sns.barplot(x='distr', y='%', data=one_st, ci=None, palette= "Greens_r")
ax.set_title("Улицы с одним объектом общественного питания в разрезе административных округов", fontsize=15)
ax.set_xlabel ("Округ")
ax.set_ylabel ("Процент")

for i in ax.patches:
        _x = i.get_x() + i.get_width() / 2
        _y = i.get_y() + i.get_height() + (i.get_height()*0.01)
        value = '{:.2f}'.format(i.get_height())
        ax.text(_x, _y, value, ha="center")
        
plt.show()

# %% [markdown]
# Вывод:
#
# - всего в датасете 476 улиц с 1 заведением
# - больше всего улиц с одним заведением в ЦАО - 31%
# - следующее значение почти в 3 раза меньше - 12% в СВАО, меньше всего улиц с одним заведением в ЮЗАО - 3,78%

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Теперь у нас есть представление об этих заведениях.
#
# </div>

# %% [markdown]
# ## Фоновая картограмма (хороплет) со средним чеком для каждого района

# %% [markdown]
# Для корректного расчета медианы, отфильтруем данные по среднему чеку, так как в столбце middle_avg_bill много пропусков.
#
# Возьмем значения не равные -1.

# %%
check_avg = data.query('middle_avg_bill != -1')
check_avg = check_avg.pivot_table(index='district', values='middle_avg_bill', aggfunc='median').sort_values(by='middle_avg_bill', ascending=False).reset_index()
check_avg
# Out:
#                                   district  middle_avg_bill
# 0          Западный административный округ             1000
# 1       Центральный административный округ             1000
# 2   Северо-Западный административный округ              700
# 3          Северный административный округ              650
# 4      Юго-Западный административный округ              600
# 5         Восточный административный округ              575
# 6  Северо-Восточный административный округ              500
# 7             Южный административный округ              500
# 8     Юго-Восточный административный округ              450

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера:</b> Все верно. В столбце со средним чеком есть выбросы, поэтому мы используем для расчета медиану.
#
# </div>

# %%
# создаём карту Москвы
m_check_avg = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=check_avg,
    columns=['district', 'middle_avg_bill'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Средний чек заведений по районам',
).add_to(m_check_avg)

# выводим карту
#m_check_avg

# %% [markdown]
# Выводы:
#
# - самый высокий средний чек в Центральном и Западном административных округах
#
# - Северный, Северо-Западный, Юго-Западный и Восточный административные округа имеют среднюю цену за чек в промежутке от 700 до 575
#
# - Северо_Восточный, Восточный и Юго-Западный административные округа имеют средний чек до 500 рублей

# %% [markdown]
# ## Влияние удалённости от центра на цены в заведениях

# %% [markdown]
# Как видно из картограммы выше, самые высокие цены в заведениях общественного питания в районах с высоким уровнем жизни: Центральный и Западный.
#
# Традиционно, восток и юг Москвы менее дорогостоящий, там средние цены значительно ниже.

# %% [markdown]
# # Детализируем исследование: открытие кофейни

# %% [markdown]
# ## Количество кофеен и их расположение

# %%
print('Всего в Москве', len(data.query('category == "кофейня"')), 'кофеен')
# Out:
# Всего в Москве 1413 кофеен

# %%
cof = data.query('category == "кофейня"').pivot_table(index='district', values='name', aggfunc='count').reset_index()\
.sort_values(by='name', ascending=False)
cof.columns = ['district', 'count']
cof
# Out:
#                                   district  count
# 5       Центральный административный округ    428
# 2          Северный административный округ    193
# 3  Северо-Восточный административный округ    159
# 1          Западный административный округ    150
# 8             Южный административный округ    131
# 0         Восточный административный округ    105
# 7      Юго-Западный административный округ     96
# 6     Юго-Восточный административный округ     89
# 4   Северо-Западный административный округ     62

# %%
# создаём карту Москвы
m_cof = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=cof,
    columns=['district', 'count'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Расположение кофеен по районам',
).add_to(m_cof)

# выводим карту
#m_cof

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> На карте выше отображаются также кластеры с общим количеством заведений. Их лучше убрать или сделать кластеры с количеством кофеен.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Удалила кластеры
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b>
#
# Здорово, такая карта подойдет.
# </div>

# %% [markdown]
# Вывод:
#
# - наибольшее количество кофеен в Центральном округе - 428 заведений
#
# - далее идут Северный, Северо-Восточный и Западный округа - там соответственно 193, 159 и 150 кофеен

# %% [markdown]
# ## Есть ли круглосуточные кофейни?

# %%
print('Количество круглосуточных кофеен', len(data.query('category == "кофейня" & is_24_7 == True')))
print('В Москве', '{:.1%}'.format(data.query('category == "кофейня"')['is_24_7'].mean()), 'круглосуточных кофеен от общего количества кофеен')
# Out:
# Количество круглосуточных кофеен 59
# В Москве 4.2% круглосуточных кофеен от общего количества кофеен

# %% [markdown]
# Посчитаем количество круглосуточных кофеен по округам Москвы.

# %%
cof_24_7 = data.query('category == "кофейня" & is_24_7 == True')
cof_24_7 = cof_24_7.pivot_table(index='district', values='name', aggfunc='count').reset_index()
cof_24_7 = cof_24_7.sort_values(by='name', ascending=False)
cof_24_7.columns = ['district', 'count']
cof_24_7
# Out:
#                                   district  count
# 5       Центральный административный округ     26
# 1          Западный административный округ      9
# 7      Юго-Западный административный округ      7
# 0         Восточный административный округ      5
# 2          Северный административный округ      5
# 3  Северо-Восточный административный округ      3
# 4   Северо-Западный административный округ      2
# 6     Юго-Восточный административный округ      1
# 8             Южный административный округ      1

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Комментарий ревьюера:</b> Кажется проект сохранился не полностью. Перед отправкой лучше нажать кнопку сохранения, и дождаться, когда оно будет создано:
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Обновила проект
# </div>

# %%
# создаём карту Москвы
m_cof_24_7 = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=cof_24_7,
    columns=['district', 'count'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Расположение кофеен по районам',
).add_to(m_cof_24_7)

# выводим карту
#m_cof_24_7

# %% [markdown]
# Выводы:
#
# - самое большое количество круглосуточных кофеен расположено в ЦАО - 26 из 59 (44%)
#
# - круглосуточные кофейни составляют всего 4,2% от общего количества кофеен
#
# - расположение круглосуточных кофеен в центре Москвы наверняка обусловлено повышенным спросом именно в этом районе

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b> Круглосуточных кофеен немного: скорее всего, они востребованы только в центре.
#
# </div>

# %% [markdown]
# ## Рейтинг кофеен и его распределение по районам

# %%
# группируем данные
cof_rating = data.query('category == "кофейня" & rating != -1').pivot_table(index='district', values='rating', aggfunc='mean').reset_index()\
.sort_values(by='rating', ascending=False)
cof_rating.columns = ['district', 'avg_rating']
cof_rating
# Out:
#                                   district  avg_rating
# 5       Центральный административный округ        4.34
# 4   Северо-Западный административный округ        4.33
# 2          Северный административный округ        4.29
# 7      Юго-Западный административный округ        4.28
# 0         Восточный административный округ        4.28
# 8             Южный административный округ        4.23
# 6     Юго-Восточный административный округ        4.23
# 3  Северо-Восточный административный округ        4.22
# 1          Западный административный округ        4.20

# %%
# создаём карту Москвы
m_rating = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём хороплет с помощью конструктора Choropleth и добавляем его на карту
Choropleth(
    geo_data=state_geo,
    data=cof_24_7,
    columns=['district', 'count'],
    key_on='feature.name',
    fill_color='YlGn',
    fill_opacity=0.8,
    legend_name='Расположение кофеен по районам',
).add_to(m_rating)

# выводим карту
#m_rating

# %% [markdown]
# Выводы:
#
# - рейтинг кофеен не сильно отличаются друг от друга и варьируется между 4.34 и 4.20
#
# - самые рейтинговые кофейни расположены все там же в ЦАО Москвы
#
# - минимальный рейтинг в кофейнях в ЗАО

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b> Да, в центре рейтинг лучше всего.
#
# </div>

# %% [markdown]
# ## Стоимость чашки капучино в кофейнях по районам

# %% [markdown]
# Опрелделим среднюю стоимость чашки кофе в разных районах Москвы.

# %%
avg_cof = data.query('category == "кофейня" & middle_coffee_cup != -1')\
.pivot_table(index='distr', values='middle_coffee_cup', aggfunc=['mean','count']).reset_index()
avg_cof.columns = ['district', 'mean_bill', 'count']
avg_cof = avg_cof.sort_values(by='mean_bill', ascending=False)
avg_cof
# Out:
#   district  mean_bill  count
# 1      ЗАО     189.94     49
# 5      ЦАО     187.52    162
# 8     ЮЗАО     184.18     34
# 0      ВАО     174.02     42
# 2      САО     165.79     76
# 4     СЗАО     165.52     21
# 3     СВАО     165.33     60
# 6      ЮАО     158.49     43
# 7     ЮВАО     151.09     34

# %%
# строим гистограмму
bar,ax = plt.subplots(figsize=(15, 9))
ax = sns.barplot(x='district', y='mean_bill', data=avg_cof, ci=None, palette= "Greens_r")
ax.set_title("Средний чек чашки кофе в разрезе административных округов", fontsize=15)
ax.set_xlabel ("Округ")
ax.set_ylabel ("Средний чек чашки кофе")

for i in ax.patches:
        _x = i.get_x() + i.get_width() / 2
        _y = i.get_y() + i.get_height() + (i.get_height()*0.01)
        value = '{:.2f}'.format(i.get_height())
        ax.text(_x, _y, value, ha="center")
        
plt.show()

# %% [markdown]
# Самая высокая стоимость чашки кофе в ЗАО - почти 190 рублей, затем следует ЦАО - 188 рублей.
#
# Цена на чашку кофе в Мокве варьируется между 190 и 150 рублями, в зависимости от района.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера 2:</b> Стоит учесть цены в других заведениях района при открытии кофейни.
#
# </div>

# %% [markdown]
# Выводы и рекомендации:
#
# - наиболее востребованная категория заведения у посетителей - это кафе, ресторан или кофейня
# - если открытие планируется в ЦАО - то следует рассмотереть еще бар,паб
# - открывать кофейню можно в любом районе Москвы, рекомендуется рассмотреть ЦАО и ЗАО
# - при открытии следует ориентироваться на конкурентов и цены: ЦАО высококонкурентный район с самыми высокими ценами, но и спрос здесь гораздо выше
# - следует рассмотреть возможность открытия сетевого заведения, например, Шоколадницу (самая популярная сеть)
# - на карте ниже можно выявить перспективные места, где еще нет кофеен
# - в исследовании выделены улицы, в том числе в ЦАО где находится одно заведение общественного питания, рекомендуется рассмотреть эти улицы

# %% [markdown]
# # Карта расположения кофеен в Москве

# %%
# выборка кофеен
coffees = data.query('category == "кофейня"')

# %%
# создаём карту Москвы
m_coffees = Map(location=[moscow_lat, moscow_lng], zoom_start=10, tiles='Cartodb Positron')

# создаём пустой кластер, добавляем его на карту
marker_cluster = MarkerCluster().add_to(m_coffees)

# пишем функцию, которая принимает строку датафрейма,
# создаёт маркер в текущей точке и добавляет его в кластер marker_cluster
def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['rating']}",
    ).add_to(marker_cluster)

# применяем функцию create_clusters() к каждой строке датафрейма
coffees.apply(create_clusters, axis=1)

# выводим карту со всеми кофейнями Москвы
m_coffees
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Общий вывод по проекту:
#
# В данном проекте было проведено исследование рынка заведений общественного питания города Москвы.
#
# Была проведена предобработка данных:
#
# - созданы новые столбцы с названием улиц и информацией о часах работы заведения
# - данные проверены на отсутствующие значения и явные и неявные дубликаты
# - заменен тип данных на целочисленный
#
# При изучении информации, мною были выявлены следующие особенности рынка общественного питания в Москве:
#
# наибольшую долю рынка общественного питания в Москве занимают:
#
# кафе - почти 28%
#
# рестораны - 24%
#
# кофейни - 17%
#
# бары, пабы - 9%
#
# По количеству посадочных мест по медианным значениям топ возглавляют следующие 3 категории заведений:
#
# ресторан – 86 мест
#
# бар,паб – 82 мест
#
# кофейня – 80 мест
#
# Количество сетевых объектов общественного питания составляет 3203 или 38,1% от всего рынка общественного питания.
#
# Сетевое распространение наиболее характерно для следующих видов объектов общественого питания:
#
# Булочная - 61%
#
# Пиццерия - 52%
#
# Кофейня - 51%
#
# В исследовании выделены ТОП-15 сетей, в который входят известные сети общественного питания.
# - всего в ТОП-15 - 816 заведений, это составляет 25% от всех сетевых
# - самой популярной сетью является - Шоколадница (120 объектов), затем идут пиццерии - Доминос Пицца и Додо Пицца
# - 41% заведений в ТОП-15 составляют кофейни
#
# Центральный административный округ сильно отличается от всех остальных районов распределением по категориям заведений – в этом округе значительно больше баров, ресторанов, кафе и кофеен.
#
# - на фоне всех округов выделяется ЦАО, в нем расположено самое большое количество заведений - 2242 или 27% от всего количества
# - больше всего в ЦАО ресторанов - 670 или 30%, заатем идут кафе, кофейни и бары
# - меньше всего в ЦАО булочных
# - лучше всего представлены во всех округах кафе от 39% до 20%, хуже всего - булочные от 4% до 2%
#
# В ходе работы с данными была выяснена интересная особенность оценки различных заведений пользователями в зависимости от категории заведения: в среднем в барах и пабах люди оставляют более высокие оценки (~ 4.4), а в заведениях быстрого питания этот показатель наиболее низкий (~ 4).
#
# - средние рейтинги категорий заведений отличаются минимально друг от друга от 4.05 до 4.39
# - самый высокий рейтинг у заведений категорий 'бар,паб', затем идут 'пиццерия' и 'ресторан', самый низкий у категории 'быстрое питание'
# - самый высокий средний рейтинг в Центральном административном округе, там больше объектов категории 'бар,паб', посетители которых оценивают выше
# - затем идут САО и СЗАО
#
# В проекте проведено исследование расположения заведений в Москве. Выделены ТОП-15 улиц по количеству заведений, где не желательно открывать новое заведение в виду высокой конкуренции и также выделены улицы с одним заведением, где менее высокая конкуренция.
# - самое большое количество заведений общественного питания находится на улице проспект Мира - 183
# - в тройку лидеров также вошли Профсоюзная улица и проспект Вернадского
# - основная часть заведений сконцентрирована в центре Москвы
# - 458 улиц с всего лишь одним заведением общественного питания
# - 31% таких улиц находится в ЦАО
#
# Средний чек по районам Москвы:
# - самый высокий средний чек в Центральном и Западном административных округах
# - Северный, Северо-Западный, Юго-Западный и Восточный административные округа имеют среднюю цену за чек в промежутке от 700 до 575
# - Северо-Восточный, Восточный и Юго-Западный административные округа имеют средний чек до 500 рублей
# - самые высокие цены в заведениях общественного питания в районах с высоким уровнем жизни: Центральный и Западный
# - восток и юг Москвы менее дорогостоящий, там средние цены значительно ниже

# %% [markdown]
# # Ссылка на презентацию

# %% [markdown]
# https://disk.yandex.ru/i/8ls41fEBqyh2rA

# %% [markdown]
# <a id="comm2"></a>
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера 2:</b>
#
# Добавь, пожалуйста, в презентацию раздел про кофейни. Например, в разделе с рекомендациями сказано, что "На карте ниже можно выявить перспективные места, где еще нет кофеен", однако в презентации такой карты нет.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Обновила презентацию картой с кофейнями в Москве.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера 2:</b> Что можно еще добавить при желании:
#
# * нумерацию страниц;
# * оглавление.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # <b>Итоговый комментарий ревьюера:</b>
#
# <div class="alert alert-success">
#
# Благодарю тебя за выполнение проекта. Видно, что ты постаралась, когда работала над ним: здорово, что все графики оформлены в одной цветовой гамме. Однако, в проекте есть несколько замечаний, которые надо исправить:
#
# * скорректировать заполнение пропусков;
# * дополнить оформление графиков;
# * заменить график с категориями сетевых заведений;
# * ответить на вопрос, к каким категориям относятся популярные сети;
# * заменить график с распределением по районам;
# * разделить хороплет и кластеры;
# * добавить ответы на вопросы про кофейни и ссылку на презентацию.
#
# Жду проект после доработки. Уверена, ты справишься. 💪
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# Дополнила проект
# </div>
